# %% [markdown]
# ## Translate Colorado stream gage data into Geoconnex

# %% [markdown]
# Source is: https://dwr.state.co.us/Tools/Stations?Stations=All&submitButton=Submit
# Data downloaded as csv and saved as xlsx

# %%
import arcpy

# Set the workspace environment
arcpy.env.workspace = r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb"

#read in table and create feature class.

# Define the paths to the Excel file and the geodatabase
excel_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CDSS_SearchResults_SurfaceWaterStations_202309261305.xlsx"
geodatabase = r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb"

# Define the name for the feature class
feature_class_name = "CO_gages"

# Define the Excel sheet name (modify as needed)
excel_sheet_name = "CDSS_SearchResults_SurfaceWater"

# Create a path to the output feature class
output_feature_class = arcpy.ValidateTableName(feature_class_name, geodatabase)


# Import the Excel table into ArcGIS Pro as a table
arcpy.ExcelToTable_conversion(excel_file, output_feature_class) #field_names_range)

# # Convert the table to a feature class
arcpy.management.XYTableToPoint(
    in_table="CO_gages",
    out_feature_class=r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb\CO_gages_XYTableToPoint",
    x_field="Longitude",
    y_field="Latitude",
    z_field=None,
    coordinate_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]];-400 -400 1000000000;-100000 10000;-100000 10000;8.98315284119521E-09;0.001;0.001;IsHighPrecision'
)

print(f"Imported '{excel_sheet_name}' from '{excel_file}' to '{geodatabase}\\{output_feature_class}'")

arcpy.conversion.ExportFeatures(
    in_features="CO_gages_XYTableToPoint",
    out_features=r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb\CO_gages_final",
    where_clause="",
    use_field_alias_as_name="NOT_USE_ALIAS",
    field_mapping='Abbrev "Abbrev" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Abbrev,0,255;Station_Name "Station Name" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Station_Name,0,255;Station_Status "Station Status" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Station_Status,0,255;Data_Source "Data Source" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Data_Source,0,255;USGS_ID "USGS ID" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,USGS_ID,0,255;WDID "WDID" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,WDID,0,255;Water_Source "Water Source" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Water_Source,0,255;GNIS_ID "GNIS ID" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,GNIS_ID,0,255;Stream_Mile "Stream Mile" true true false 8 Double 0 0,First,#,CO_gages_XYTableToPoint,Stream_Mile,-1,-1;POR_Start "POR Start" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,POR_Start,0,255;POR_End "POR End" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,POR_End,0,255;Div "Div" true true false 4 Long 0 0,First,#,CO_gages_XYTableToPoint,Div,-1,-1;WD "WD" true true false 4 Long 0 0,First,#,CO_gages_XYTableToPoint,WD,-1,-1;County "County" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,County,0,255;State "State" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,State,0,255;HUC10 "HUC10" true true false 4 Long 0 0,First,#,CO_gages_XYTableToPoint,HUC10,-1,-1;UTM_X "UTM X" true true false 8 Double 0 0,First,#,CO_gages_XYTableToPoint,UTM_X,-1,-1;UTM_Y "UTM Y" true true false 8 Double 0 0,First,#,CO_gages_XYTableToPoint,UTM_Y,-1,-1;Latitude "Latitude" true true false 8 Double 0 0,First,#,CO_gages_XYTableToPoint,Latitude,-1,-1;Longitude "Longitude" true true false 8 Double 0 0,First,#,CO_gages_XYTableToPoint,Longitude,-1,-1;Location_Accuracy "Location Accuracy" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,Location_Accuracy,0,255;Modified "Modified" true true false 8 Date 0 0,First,#,CO_gages_XYTableToPoint,Modified,-1,-1;More_Information "More Information" true true false 255 Text 0 0,First,#,CO_gages_XYTableToPoint,More_Information,0,255',
    sort_field=None
)
# reassign variable name
CO_gage = "CO_gages_final"

# Define a list of field names and their types
field_list = [
    ("uri", "TEXT"),
    ("name", "TEXT"),
    ("id", "TEXT"),
    ("provider_name", "TEXT"),
    ("provider_id", "TEXT"),
    ("provider_url", "TEXT"),
    ("provider_code", "TEXT"),
    ("mainstem_uri", "TEXT"),
    ("comid", "TEXT")
]

# Add the new fields using a loop
for field_name, field_type in field_list:
    arcpy.AddField_management(CO_gage, field_name, field_type)

# Confirm the field addition
field_names = [field.name for field in arcpy.ListFields(CO_gage)]
print("Fields in the layer after addition:", field_names)
# Out:
# Imported 'CDSS_SearchResults_SurfaceWater' from 'C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CDSS_SearchResults_SurfaceWaterStations_202309261305.xlsx' to 'C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb\CO_gages'
# Fields in the layer after addition: ['OBJECTID', 'Shape', 'Abbrev', 'Station_Name', 'Station_Status', 'Data_Source', 'USGS_ID', 'WDID', 'Water_Source', 'GNIS_ID', 'Stream_Mile', 'POR_Start', 'POR_End', 'Div', 'WD', 'County', 'State', 'HUC10', 'UTM_X', 'UTM_Y', 'Latitude', 'Longitude', 'Location_Accuracy', 'Modified', 'More_Information', 'uri', 'name', 'id', 'provider_name', 'provider_id', 'provider_url', 'provider_code', 'mainstem_uri', 'comid']

# %%
# Remove USGS Gages by selecting them

CO_gage = "CO_gages_final"

arcpy.management.SelectLayerByAttribute(
    in_layer_or_view=CO_gage,
    selection_type="NEW_SELECTION",
    where_clause="Data_Source = 'U.S. Geological Survey'",
    invert_where_clause=None
)
# Delete the selected rows
arcpy.management.DeleteRows(CO_gage)

# Clear the selection
arcpy.management.SelectLayerByAttribute(
    in_layer_or_view=CO_gage,
    selection_type="CLEAR_SELECTION"
)

print("Removed USGS gages")
# Out:
# Removed USGS gages

# %%
## Get unique ID, which comes from last text after / in url 

# Create an update cursor to iterate through the rows

with arcpy.da.UpdateCursor(CO_gage, ["More_Information", "id"]) as cursor:
    for row in cursor:
        more_info_url = row[0]
        parts = more_info_url.split('/')
        last_part = parts[-1]
        row[1] = last_part  # Set the 'id' field to the extracted value
        cursor.updateRow(row)
        print(row)

# Clean up the cursor
del cursor

# Set name = id
# Define the expression for the field calculation
expression = "!id!"  # Set the 'name' field equal to the 'id' field

# Perform the field calculation
arcpy.management.CalculateField(CO_gage, "name", expression, "PYTHON3")

print("id and name fields populated")
# Out:
# ['https://dwr.state.co.us/Tools/Stations/7805', '7805']
# ['https://dwr.state.co.us/Tools/Stations/0101794A', '0101794A']
# ['https://dwr.state.co.us/Tools/Stations/0200616A', '0200616A']
# ['https://dwr.state.co.us/Tools/Stations/0200619A', '0200619A']
# ['https://dwr.state.co.us/Tools/Stations/0202990A', '0202990A']
# ['https://dwr.state.co.us/Tools/Stations/0202992A', '0202992A']
# ['https://dwr.state.co.us/Tools/Stations/0202993A', '0202993A']
# ['https://dwr.state.co.us/Tools/Stations/0202994A', '0202994A']
# ['https://dwr.state.co.us/Tools/Stations/0203007A', '0203007A']
# ['https://dwr.state.co.us/Tools/Stations/0203358A', '0203358A']
# ['https://dwr.state.co.us/Tools/Stations/0203700A', '0203700A']
# ['https://dwr.state.co.us/Tools/Stations/0300907A', '0300907A']
# ['https://dwr.state.co.us/Tools/Stations/0500536A', '0500536A']
# ['https://dwr.state.co.us/Tools/Stations/0502407A', '0502407A']
# ['https://dwr.state.co.us/Tools/Stations/0504010A', '0504010A']
# ['https://dwr.state.co.us/Tools/Stations/0801004A', '0801004A']
# ['https://dwr.state.co.us/Tools/Stations/0801015A', '0801015A']
# ['https://dwr.state.co.us/Tools/Stations/0802901A', '0802901A']
# ['https://dwr.state.co.us/Tools/Stations/0803405B', '0803405B']
# ['https://dwr.state.co.us/Tools/Stations/0803406A', '0803406A']
# ['https://dwr.state.co.us/Tools/Stations/0803407A', '0803407A']
# ['https://dwr.state.co.us/Tools/Stations/0900535A', '0900535A']
# ['https://dwr.state.co.us/Tools/Stations/0900752A', '0900752A']
# ['https://dwr.state.co.us/Tools/Stations/0900767A', '0900767A']
# ['https://dwr.state.co.us/Tools/Stations/0900862A', '0900862A']
# ['https://dwr.state.co.us/Tools/Stations/0900903A', '0900903A']
# ['https://dwr.state.co.us/Tools/Stations/0900955A', '0900955A']
# ['https://dwr.state.co.us/Tools/Stations/0902251A', '0902251A']
# ['https://dwr.state.co.us/Tools/Stations/0903343A', '0903343A']
# ['https://dwr.state.co.us/Tools/Stations/0904274A', '0904274A']
# ['https://dwr.state.co.us/Tools/Stations/0904295A', '0904295A']
# ['https://dwr.state.co.us/Tools/Stations/1201151A', '1201151A']
# ['https://dwr.state.co.us/Tools/Stations/1201156A', '1201156A']
# ['https://dwr.state.co.us/Tools/Stations/124OUTCO', '124OUTCO']
# ['https://dwr.state.co.us/Tools/Stations/124RTNCO', '124RTNCO']
# ['https://dwr.state.co.us/Tools/Stations/1400539A', '1400539A']
# ['https://dwr.state.co.us/Tools/Stations/1400589A', '1400589A']
# ['https://dwr.state.co.us/Tools/Stations/1400589B', '1400589B']
# ['https://dwr.state.co.us/Tools/Stations/1400618A', '1400618A']
# ['https://dwr.state.co.us/Tools/Stations/1400620A', '1400620A']
# ['https://dwr.state.co.us/Tools/Stations/1400625A', '1400625A']
# ['https://dwr.state.co.us/Tools/Stations/1400627A', '1400627A']
# ['https://dwr.state.co.us/Tools/Stations/1400639A', '1400639A']
# ['https://dwr.state.co.us/Tools/Stations/1400738A', '1400738A']
# ['https://dwr.state.co.us/Tools/Stations/1403593C', '1403593C']
# ['https://dwr.state.co.us/Tools/Stations/1413796A', '1413796A']
# ['https://dwr.state.co.us/Tools/Stations/2002034A', '2002034A']
# ['https://dwr.state.co.us/Tools/Stations/2002035A', '2002035A']
# ['https://dwr.state.co.us/Tools/Stations/2002055A', '2002055A']
# ['https://dwr.state.co.us/Tools/Stations/2002056A', '2002056A']
# ['https://dwr.state.co.us/Tools/Stations/2007012A', '2007012A']
# ['https://dwr.state.co.us/Tools/Stations/2007026A', '2007026A']
# ['https://dwr.state.co.us/Tools/Stations/2007036A', '2007036A']
# ['https://dwr.state.co.us/Tools/Stations/2007039A', '2007039A']
# ['https://dwr.state.co.us/Tools/Stations/2007047A', '2007047A']
# ['https://dwr.state.co.us/Tools/Stations/2007057A', '2007057A']
# ['https://dwr.state.co.us/Tools/Stations/2200509A', '2200509A']
# ['https://dwr.state.co.us/Tools/Stations/2200539A', '2200539A']
# ['https://dwr.state.co.us/Tools/Stations/2200541A', '2200541A']
# ['https://dwr.state.co.us/Tools/Stations/2200553A', '2200553A']
# ['https://dwr.state.co.us/Tools/Stations/2200554A', '2200554A']
# ['https://dwr.state.co.us/Tools/Stations/2200576A', '2200576A']
# ['https://dwr.state.co.us/Tools/Stations/2200587A', '2200587A']
# ['https://dwr.state.co.us/Tools/Stations/2200604A', '2200604A']
# ['https://dwr.state.co.us/Tools/Stations/2200616A', '2200616A']
# ['https://dwr.state.co.us/Tools/Stations/2200618A', '2200618A']
# ['https://dwr.state.co.us/Tools/Stations/2200624A', '2200624A']
# ['https://dwr.state.co.us/Tools/Stations/2200627A', '2200627A']
# ['https://dwr.state.co.us/Tools/Stations/2200630A', '2200630A']
# ['https://dwr.state.co.us/Tools/Stations/2200631A', '2200631A']
# ['https://dwr.state.co.us/Tools/Stations/2200632A', '2200632A']
# ['https://dwr.state.co.us/Tools/Stations/2300651A', '2300651A']
# ['https://dwr.state.co.us/Tools/Stations/2303981A', '2303981A']
# ['https://dwr.state.co.us/Tools/Stations/2402011A', '2402011A']
# ['https://dwr.state.co.us/Tools/Stations/2500571A', '2500571A']
# ['https://dwr.state.co.us/Tools/Stations/3200700A', '3200700A']
# ['https://dwr.state.co.us/Tools/Stations/3200702A', '3200702A']
# ['https://dwr.state.co.us/Tools/Stations/3403747A', '3403747A']
# ['https://dwr.state.co.us/Tools/Stations/3800881A', '3800881A']
# ['https://dwr.state.co.us/Tools/Stations/4003198A', '4003198A']
# ['https://dwr.state.co.us/Tools/Stations/4100577A', '4100577A']
# ['https://dwr.state.co.us/Tools/Stations/4100841A', '4100841A']
# ['https://dwr.state.co.us/Tools/Stations/4200506A', '4200506A']
# ['https://dwr.state.co.us/Tools/Stations/4303334A', '4303334A']
# ['https://dwr.state.co.us/Tools/Stations/4402543A', '4402543A']
# ['https://dwr.state.co.us/Tools/Stations/4500693A', '4500693A']
# ['https://dwr.state.co.us/Tools/Stations/4900512A', '4900512A']
# ['https://dwr.state.co.us/Tools/Stations/5302036A', '5302036A']
# ['https://dwr.state.co.us/Tools/Stations/6200560A', '6200560A']
# ['https://dwr.state.co.us/Tools/Stations/6200561A', '6200561A']
# ['https://dwr.state.co.us/Tools/Stations/6200561A', '6200561A']
# ['https://dwr.state.co.us/Tools/Stations/6202065A', '6202065A']
# ['https://dwr.state.co.us/Tools/Stations/6500507A', '6500507A']
# ['https://dwr.state.co.us/Tools/Stations/6500517A', '6500517A']
# ['https://dwr.state.co.us/Tools/Stations/6502402A', '6502402A']
# ['https://dwr.state.co.us/Tools/Stations/6502403A', '6502403A']
# ['https://dwr.state.co.us/Tools/Stations/70LLINCO', '70LLINCO']
# ['https://dwr.state.co.us/Tools/Stations/70ROUTCO', '70ROUTCO']
# ['https://dwr.state.co.us/Tools/Stations/70RRINCO', '70RRINCO']
# ['https://dwr.state.co.us/Tools/Stations/7100609A', '7100609A']
# ['https://dwr.state.co.us/Tools/Stations/7100618A', '7100618A']
# ['https://dwr.state.co.us/Tools/Stations/7102002A', '7102002A']
# ['https://dwr.state.co.us/Tools/Stations/8000667A', '8000667A']
# ['https://dwr.state.co.us/Tools/Stations/8000668A', '8000668A']
# ['https://dwr.state.co.us/Tools/Stations/8002400A', '8002400A']
# ['https://dwr.state.co.us/Tools/Stations/8003522A', '8003522A']
# ['https://dwr.state.co.us/Tools/Stations/8003526A', '8003526A']
# ['https://dwr.state.co.us/Tools/Stations/ABBDITCO', 'ABBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ABCLATCO', 'ABCLATCO']
# ['https://dwr.state.co.us/Tools/Stations/ABRJPOCO', 'ABRJPOCO']
# ['https://dwr.state.co.us/Tools/Stations/ADANETCO', 'ADANETCO']
# ['https://dwr.state.co.us/Tools/Stations/ADATUNCO', 'ADATUNCO']
# ['https://dwr.state.co.us/Tools/Stations/ADOAARCO', 'ADOAARCO']
# ['https://dwr.state.co.us/Tools/Stations/ADOBARCO', 'ADOBARCO']
# ['https://dwr.state.co.us/Tools/Stations/ADOVALCO', 'ADOVALCO']
# ['https://dwr.state.co.us/Tools/Stations/AGGDITCO', 'AGGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/AGGLKWCO', 'AGGLKWCO']
# ['https://dwr.state.co.us/Tools/Stations/AGGRTNCO', 'AGGRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/AHOMPLCO', 'AHOMPLCO']
# ['https://dwr.state.co.us/Tools/Stations/ALABELCO', 'ALABELCO']
# ['https://dwr.state.co.us/Tools/Stations/ALACANCO', 'ALACANCO']
# ['https://dwr.state.co.us/Tools/Stations/ALACASCO', 'ALACASCO']
# ['https://dwr.state.co.us/Tools/Stations/ALARANCO', 'ALARANCO']
# ['https://dwr.state.co.us/Tools/Stations/ALATERCO', 'ALATERCO']
# ['https://dwr.state.co.us/Tools/Stations/ALAWIGCO', 'ALAWIGCO']
# ['https://dwr.state.co.us/Tools/Stations/ALFECKCO', 'ALFECKCO']
# ['https://dwr.state.co.us/Tools/Stations/ALFFRUCO', 'ALFFRUCO']
# ['https://dwr.state.co.us/Tools/Stations/ALSOUTCO', 'ALSOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/AMYCANCO', 'AMYCANCO']
# ['https://dwr.state.co.us/Tools/Stations/ANDDITCO', 'ANDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ANFDITCO', 'ANFDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ANIHOWCO', 'ANIHOWCO']
# ['https://dwr.state.co.us/Tools/Stations/ANTFLOCO', 'ANTFLOCO']
# ['https://dwr.state.co.us/Tools/Stations/APGTUNCO', 'APGTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/AR151ECO', 'AR151ECO']
# ['https://dwr.state.co.us/Tools/Stations/AR201WCO', 'AR201WCO']
# ['https://dwr.state.co.us/Tools/Stations/AR205ECO', 'AR205ECO']
# ['https://dwr.state.co.us/Tools/Stations/AR230GCO', 'AR230GCO']
# ['https://dwr.state.co.us/Tools/Stations/AR230LCO', 'AR230LCO']
# ['https://dwr.state.co.us/Tools/Stations/ARF027CO', 'ARF027CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF049CO', 'ARF049CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF125CO', 'ARF125CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF126CO', 'ARF126CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF145CO', 'ARF145CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF14SCO', 'ARF14SCO']
# ['https://dwr.state.co.us/Tools/Stations/ARF160CO', 'ARF160CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF162CO', 'ARF162CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF166CO', 'ARF166CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF16TCO', 'ARF16TCO']
# ['https://dwr.state.co.us/Tools/Stations/ARF181CO', 'ARF181CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF182CO', 'ARF182CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF201CO', 'ARF201CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF205CO', 'ARF205CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF259CO', 'ARF259CO']
# ['https://dwr.state.co.us/Tools/Stations/ARF27LCO', 'ARF27LCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKAMCCO', 'ARKAMCCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKCA2CO', 'ARKCA2CO']
# ['https://dwr.state.co.us/Tools/Stations/ARKCACCO', 'ARKCACCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKCANCO', 'ARKCANCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKCARCO', 'ARKCARCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKCATCO', 'ARKCATCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKGRNCO', 'ARKGRNCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKLAJCO', 'ARKLAJCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKNEPC2', 'ARKNEPC2']
# ['https://dwr.state.co.us/Tools/Stations/ARKNEPCO', 'ARKNEPCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKOXFCO', 'ARKOXFCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKPORCO', 'ARKPORCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKPUECO', 'ARKPUECO']
# ['https://dwr.state.co.us/Tools/Stations/ARKROCCO', 'ARKROCCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKSALCO', 'ARKSALCO']
# ['https://dwr.state.co.us/Tools/Stations/ARKWELCO', 'ARKWELCO']
# ['https://dwr.state.co.us/Tools/Stations/ARTCANCO', 'ARTCANCO']
# ['https://dwr.state.co.us/Tools/Stations/ARVAUGCO', 'ARVAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/ARVINLCO', 'ARVINLCO']
# ['https://dwr.state.co.us/Tools/Stations/ARVRCKCO', 'ARVRCKCO']
# ['https://dwr.state.co.us/Tools/Stations/ARVRDBCO', 'ARVRDBCO']
# ['https://dwr.state.co.us/Tools/Stations/AURAM2CO', 'AURAM2CO']
# ['https://dwr.state.co.us/Tools/Stations/AURRAMCO', 'AURRAMCO']
# ['https://dwr.state.co.us/Tools/Stations/AURSTRCO', 'AURSTRCO']
# ['https://dwr.state.co.us/Tools/Stations/AZOTUNNM', 'AZOTUNNM']
# ['https://dwr.state.co.us/Tools/Stations/BARDITCO', 'BARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BASBBACO', 'BASBBACO']
# ['https://dwr.state.co.us/Tools/Stations/BASMOUCO', 'BASMOUCO']
# ['https://dwr.state.co.us/Tools/Stations/BASOUTCO', 'BASOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BCACOACO', 'BCACOACO']
# ['https://dwr.state.co.us/Tools/Stations/BCRMORCO', 'BCRMORCO']
# ['https://dwr.state.co.us/Tools/Stations/BCROUTCO', 'BCROUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BCRSHECO', 'BCRSHECO']
# ['https://dwr.state.co.us/Tools/Stations/BCSCBCCO', 'BCSCBCCO']
# ['https://dwr.state.co.us/Tools/Stations/BEAPORCO', 'BEAPORCO']
# ['https://dwr.state.co.us/Tools/Stations/BEAVERCO', 'BEAVERCO']
# ['https://dwr.state.co.us/Tools/Stations/BEEDITCO', 'BEEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BELLN1CO', 'BELLN1CO']
# ['https://dwr.state.co.us/Tools/Stations/BELLN3CO', 'BELLN3CO']
# ['https://dwr.state.co.us/Tools/Stations/BERBBLCO', 'BERBBLCO']
# ['https://dwr.state.co.us/Tools/Stations/BERCR7CO', 'BERCR7CO']
# ['https://dwr.state.co.us/Tools/Stations/BERDITCO', 'BERDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BEROUTCO', 'BEROUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BERSOUCO', 'BERSOUCO']
# ['https://dwr.state.co.us/Tools/Stations/BESDITCO', 'BESDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BEVBEVCO', 'BEVBEVCO']
# ['https://dwr.state.co.us/Tools/Stations/BFCINFCO', 'BFCINFCO']
# ['https://dwr.state.co.us/Tools/Stations/BFCLHCCO', 'BFCLHCCO']
# ['https://dwr.state.co.us/Tools/Stations/BFCLYOCO', 'BFCLYOCO']
# ['https://dwr.state.co.us/Tools/Stations/BHEATNCO', 'BHEATNCO']
# ['https://dwr.state.co.us/Tools/Stations/BHERTNCO', 'BHERTNCO']
# ['https://dwr.state.co.us/Tools/Stations/BHNPRKCO', 'BHNPRKCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGDAFCO', 'BIGDAFCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGDITCO', 'BIGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGHILCO', 'BIGHILCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGLASCO', 'BIGLASCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGLKDCO', 'BIGLKDCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGMONCO', 'BIGMONCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGSPGCO', 'BIGSPGCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGSURCO', 'BIGSURCO']
# ['https://dwr.state.co.us/Tools/Stations/BIGUPPCO', 'BIGUPPCO']
# ['https://dwr.state.co.us/Tools/Stations/BIJOUSCO', 'BIJOUSCO']
# ['https://dwr.state.co.us/Tools/Stations/BKIOUTCO', 'BKIOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BLADIVCO', 'BLADIVCO']
# ['https://dwr.state.co.us/Tools/Stations/BLARESCO', 'BLARESCO']
# ['https://dwr.state.co.us/Tools/Stations/BLDLHDCO', 'BLDLHDCO']
# ['https://dwr.state.co.us/Tools/Stations/BLDRLHCO', 'BLDRLHCO']
# ['https://dwr.state.co.us/Tools/Stations/BLKRSOCO', 'BLKRSOCO']
# ['https://dwr.state.co.us/Tools/Stations/BLUDITCO', 'BLUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BLUNINCO', 'BLUNINCO']
# ['https://dwr.state.co.us/Tools/Stations/BLWDITCO', 'BLWDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BMLDITCO', 'BMLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BMSVRTCO', 'BMSVRTCO']
# ['https://dwr.state.co.us/Tools/Stations/BNSVPPCO', 'BNSVPPCO']
# ['https://dwr.state.co.us/Tools/Stations/BOBCRKCO', 'BOBCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/BOBGLNCO', 'BOBGLNCO']
# ['https://dwr.state.co.us/Tools/Stations/BOC109CO', 'BOC109CO']
# ['https://dwr.state.co.us/Tools/Stations/BOCBBRCO', 'BOCBBRCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCBGRCO', 'BOCBGRCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCBROCO', 'BOCBROCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCELSCO', 'BOCELSCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCMIDCO', 'BOCMIDCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCOBOCO', 'BOCOBOCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCOROCO', 'BOCOROCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCPINCO', 'BOCPINCO']
# ['https://dwr.state.co.us/Tools/Stations/BOCWLMCO', 'BOCWLMCO']
# ['https://dwr.state.co.us/Tools/Stations/BODITLCO', 'BODITLCO']
# ['https://dwr.state.co.us/Tools/Stations/BONDITCO', 'BONDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BORDITCO', 'BORDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BOSDAMCO', 'BOSDAMCO']
# ['https://dwr.state.co.us/Tools/Stations/BOSDELCO', 'BOSDELCO']
# ['https://dwr.state.co.us/Tools/Stations/BOUBYPCO', 'BOUBYPCO']
# ['https://dwr.state.co.us/Tools/Stations/BOULARCO', 'BOULARCO']
# ['https://dwr.state.co.us/Tools/Stations/BOUTUNCO', 'BOUTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/BOXDITCO', 'BOXDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BOXHUDCO', 'BOXHUDCO']
# ['https://dwr.state.co.us/Tools/Stations/BP2OUTCO', 'BP2OUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BREOUTCO', 'BREOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/BRGDITCO', 'BRGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BRISEWCO', 'BRISEWCO']
# ['https://dwr.state.co.us/Tools/Stations/BRITAICO', 'BRITAICO']
# ['https://dwr.state.co.us/Tools/Stations/BRKRESCO', 'BRKRESCO']
# ['https://dwr.state.co.us/Tools/Stations/BRNINLCO', 'BRNINLCO']
# ['https://dwr.state.co.us/Tools/Stations/BRTDITCO', 'BRTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BRTWSTCO', 'BRTWSTCO']
# ['https://dwr.state.co.us/Tools/Stations/BRVDITCO', 'BRVDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BTABCMCO', 'BTABCMCO']
# ['https://dwr.state.co.us/Tools/Stations/BTABESCO', 'BTABESCO']
# ['https://dwr.state.co.us/Tools/Stations/BTBLCMCO', 'BTBLCMCO']
# ['https://dwr.state.co.us/Tools/Stations/BTBLESCO', 'BTBLESCO']
# ['https://dwr.state.co.us/Tools/Stations/BTCANYCO', 'BTCANYCO']
# ['https://dwr.state.co.us/Tools/Stations/BTNFDRCO', 'BTNFDRCO']
# ['https://dwr.state.co.us/Tools/Stations/BTPLADCO', 'BTPLADCO']
# ['https://dwr.state.co.us/Tools/Stations/BTPLBPCO', 'BTPLBPCO']
# ['https://dwr.state.co.us/Tools/Stations/BTPPMCCO', 'BTPPMCCO']
# ['https://dwr.state.co.us/Tools/Stations/BUCRMVCO', 'BUCRMVCO']
# ['https://dwr.state.co.us/Tools/Stations/BUFDITCO', 'BUFDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BULLCRCO', 'BULLCRCO']
# ['https://dwr.state.co.us/Tools/Stations/BURAUGCO', 'BURAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/BURCANCO', 'BURCANCO']
# ['https://dwr.state.co.us/Tools/Stations/BURDITCO', 'BURDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BUSTUNCO', 'BUSTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/BVRWP3CO', 'BVRWP3CO']
# ['https://dwr.state.co.us/Tools/Stations/BWCDITCO', 'BWCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BWRDITCO', 'BWRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/BWRTO1CO', 'BWRTO1CO']
# ['https://dwr.state.co.us/Tools/Stations/BWRTO2CO', 'BWRTO2CO']
# ['https://dwr.state.co.us/Tools/Stations/BYDRTNCO', 'BYDRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/CABCRECO', 'CABCRECO']
# ['https://dwr.state.co.us/Tools/Stations/CANAL3CO', 'CANAL3CO']
# ['https://dwr.state.co.us/Tools/Stations/CANSWKCO', 'CANSWKCO']
# ['https://dwr.state.co.us/Tools/Stations/CAPDCPCO', 'CAPDCPCO']
# ['https://dwr.state.co.us/Tools/Stations/CAPDITCO', 'CAPDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CARDITCO', 'CARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CARLAGCO', 'CARLAGCO']
# ['https://dwr.state.co.us/Tools/Stations/CASCANCO', 'CASCANCO']
# ['https://dwr.state.co.us/Tools/Stations/CASCRKCO', 'CASCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/CASTACCO', 'CASTACCO']
# ['https://dwr.state.co.us/Tools/Stations/CATAGCCO', 'CATAGCCO']
# ['https://dwr.state.co.us/Tools/Stations/CATAGTCO', 'CATAGTCO']
# ['https://dwr.state.co.us/Tools/Stations/CATCANCO', 'CATCANCO']
# ['https://dwr.state.co.us/Tools/Stations/CBPALACO', 'CBPALACO']
# ['https://dwr.state.co.us/Tools/Stations/CCACC2CO', 'CCACC2CO']
# ['https://dwr.state.co.us/Tools/Stations/CCACCRCO', 'CCACCRCO']
# ['https://dwr.state.co.us/Tools/Stations/CCBCCRCO', 'CCBCCRCO']
# ['https://dwr.state.co.us/Tools/Stations/CEFAUGCO', 'CEFAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/CENCANCO', 'CENCANCO']
# ['https://dwr.state.co.us/Tools/Stations/CENFULCO', 'CENFULCO']
# ['https://dwr.state.co.us/Tools/Stations/CENGODCO', 'CENGODCO']
# ['https://dwr.state.co.us/Tools/Stations/CENJNZCO', 'CENJNZCO']
# ['https://dwr.state.co.us/Tools/Stations/CENKNGCO', 'CENKNGCO']
# ['https://dwr.state.co.us/Tools/Stations/CENTLBCO', 'CENTLBCO']
# ['https://dwr.state.co.us/Tools/Stations/CGSEWECO', 'CGSEWECO']
# ['https://dwr.state.co.us/Tools/Stations/CHAFISCO', 'CHAFISCO']
# ['https://dwr.state.co.us/Tools/Stations/CHAGULCO', 'CHAGULCO']
# ['https://dwr.state.co.us/Tools/Stations/CHCRNACO', 'CHCRNACO']
# ['https://dwr.state.co.us/Tools/Stations/CHECKSCO', 'CHECKSCO']
# ['https://dwr.state.co.us/Tools/Stations/CHECRECO', 'CHECRECO']
# ['https://dwr.state.co.us/Tools/Stations/CHEREDCO', 'CHEREDCO']
# ['https://dwr.state.co.us/Tools/Stations/CHERESCO', 'CHERESCO']
# ['https://dwr.state.co.us/Tools/Stations/CHERTNCO', 'CHERTNCO']
# ['https://dwr.state.co.us/Tools/Stations/CHIAUGCO', 'CHIAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/CHIDEVCO', 'CHIDEVCO']
# ['https://dwr.state.co.us/Tools/Stations/CHIDITCO', 'CHIDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CHIIDSCO', 'CHIIDSCO']
# ['https://dwr.state.co.us/Tools/Stations/CHUAUGCO', 'CHUAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/CHUDITCO', 'CHUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CHURALCO', 'CHURALCO']
# ['https://dwr.state.co.us/Tools/Stations/CILDITCO', 'CILDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CIRDITCO', 'CIRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CLACANCO', 'CLACANCO']
# ['https://dwr.state.co.us/Tools/Stations/CLAFTCCO', 'CLAFTCCO']
# ['https://dwr.state.co.us/Tools/Stations/CLAGRECO', 'CLAGRECO']
# ['https://dwr.state.co.us/Tools/Stations/CLAIRRCO', 'CLAIRRCO']
# ['https://dwr.state.co.us/Tools/Stations/CLAKODCO', 'CLAKODCO']
# ['https://dwr.state.co.us/Tools/Stations/CLANSECO', 'CLANSECO']
# ['https://dwr.state.co.us/Tools/Stations/CLAPOUCO', 'CLAPOUCO']
# ['https://dwr.state.co.us/Tools/Stations/CLARIVCO', 'CLARIVCO']
# ['https://dwr.state.co.us/Tools/Stations/CLASRKCO', 'CLASRKCO']
# ['https://dwr.state.co.us/Tools/Stations/CLAWASCO', 'CLAWASCO']
# ['https://dwr.state.co.us/Tools/Stations/CLECROCO', 'CLECROCO']
# ['https://dwr.state.co.us/Tools/Stations/CLEDERCO', 'CLEDERCO']
# ['https://dwr.state.co.us/Tools/Stations/CLEGLKCO', 'CLEGLKCO']
# ['https://dwr.state.co.us/Tools/Stations/CLFOFDCO', 'CLFOFDCO']
# ['https://dwr.state.co.us/Tools/Stations/CLFOFDCO', 'CLFOFDCO']
# ['https://dwr.state.co.us/Tools/Stations/CLODITCO', 'CLODITCO']
# ['https://dwr.state.co.us/Tools/Stations/CLPDITCO', 'CLPDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CNBTPRCO', 'CNBTPRCO']
# ['https://dwr.state.co.us/Tools/Stations/COADITCO', 'COADITCO']
# ['https://dwr.state.co.us/Tools/Stations/COCRBVCO', 'COCRBVCO']
# ['https://dwr.state.co.us/Tools/Stations/COCREPCO', 'COCREPCO']
# ['https://dwr.state.co.us/Tools/Stations/COCRESCO', 'COCRESCO']
# ['https://dwr.state.co.us/Tools/Stations/COCRHSCO', 'COCRHSCO']
# ['https://dwr.state.co.us/Tools/Stations/COCRMICO', 'COCRMICO']
# ['https://dwr.state.co.us/Tools/Stations/COLCANCO', 'COLCANCO']
# ['https://dwr.state.co.us/Tools/Stations/COLCHICO', 'COLCHICO']
# ['https://dwr.state.co.us/Tools/Stations/COLDITCO', 'COLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/COLGRAND', 'COLGRAND']
# ['https://dwr.state.co.us/Tools/Stations/COLKBDCO', 'COLKBDCO']
# ['https://dwr.state.co.us/Tools/Stations/COLPARCO', 'COLPARCO']
# ['https://dwr.state.co.us/Tools/Stations/COLSULCO', 'COLSULCO']
# ['https://dwr.state.co.us/Tools/Stations/COMRETCO', 'COMRETCO']
# ['https://dwr.state.co.us/Tools/Stations/COMSPWCO', 'COMSPWCO']
# ['https://dwr.state.co.us/Tools/Stations/CONCONCO', 'CONCONCO']
# ['https://dwr.state.co.us/Tools/Stations/COND20CO', 'COND20CO']
# ['https://dwr.state.co.us/Tools/Stations/COND26CO', 'COND26CO']
# ['https://dwr.state.co.us/Tools/Stations/CONDITCO', 'CONDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CONMANCO', 'CONMANCO']
# ['https://dwr.state.co.us/Tools/Stations/CONMOGCO', 'CONMOGCO']
# ['https://dwr.state.co.us/Tools/Stations/CONPLACO', 'CONPLACO']
# ['https://dwr.state.co.us/Tools/Stations/COOB2LCO', 'COOB2LCO']
# ['https://dwr.state.co.us/Tools/Stations/COOB4LCO', 'COOB4LCO']
# ['https://dwr.state.co.us/Tools/Stations/COOB7LCO', 'COOB7LCO']
# ['https://dwr.state.co.us/Tools/Stations/COOBY2CO', 'COOBY2CO']
# ['https://dwr.state.co.us/Tools/Stations/COOTRECO', 'COOTRECO']
# ['https://dwr.state.co.us/Tools/Stations/CORDITCO', 'CORDITCO']
# ['https://dwr.state.co.us/Tools/Stations/COSDITCO', 'COSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/COTDITCO', 'COTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/COTPIPCO', 'COTPIPCO']
# ['https://dwr.state.co.us/Tools/Stations/COWCRKCO', 'COWCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/CRBRLVCO', 'CRBRLVCO']
# ['https://dwr.state.co.us/Tools/Stations/CRHBLVCO', 'CRHBLVCO']
# ['https://dwr.state.co.us/Tools/Stations/CRHW10CO', 'CRHW10CO']
# ['https://dwr.state.co.us/Tools/Stations/CRIDITCO', 'CRIDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CRSAGDCO', 'CRSAGDCO']
# ['https://dwr.state.co.us/Tools/Stations/CRSAP3CO', 'CRSAP3CO']
# ['https://dwr.state.co.us/Tools/Stations/CRSAS1CO', 'CRSAS1CO']
# ['https://dwr.state.co.us/Tools/Stations/CRSHW1CO', 'CRSHW1CO']
# ['https://dwr.state.co.us/Tools/Stations/CRSHW2CO', 'CRSHW2CO']
# ['https://dwr.state.co.us/Tools/Stations/CRSINDCO', 'CRSINDCO']
# ['https://dwr.state.co.us/Tools/Stations/CRSRTNCO', 'CRSRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/CRSSLPCO', 'CRSSLPCO']
# ['https://dwr.state.co.us/Tools/Stations/CRUGULCO', 'CRUGULCO']
# ['https://dwr.state.co.us/Tools/Stations/CRYCRMCO', 'CRYCRMCO']
# ['https://dwr.state.co.us/Tools/Stations/CRYDOWCO', 'CRYDOWCO']
# ['https://dwr.state.co.us/Tools/Stations/CRYNETCO', 'CRYNETCO']
# ['https://dwr.state.co.us/Tools/Stations/CRYTHOCO', 'CRYTHOCO']
# ['https://dwr.state.co.us/Tools/Stations/CTWINLCO', 'CTWINLCO']
# ['https://dwr.state.co.us/Tools/Stations/CTWRESCO', 'CTWRESCO']
# ['https://dwr.state.co.us/Tools/Stations/CTYDITCO', 'CTYDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CUCBCRCO', 'CUCBCRCO']
# ['https://dwr.state.co.us/Tools/Stations/CUCHUECO', 'CUCHUECO']
# ['https://dwr.state.co.us/Tools/Stations/CULCHACO', 'CULCHACO']
# ['https://dwr.state.co.us/Tools/Stations/CULDITCO', 'CULDITCO']
# ['https://dwr.state.co.us/Tools/Stations/CULSANCO', 'CULSANCO']
# ['https://dwr.state.co.us/Tools/Stations/CUMDELCO', 'CUMDELCO']
# ['https://dwr.state.co.us/Tools/Stations/CUNCANCO', 'CUNCANCO']
# ['https://dwr.state.co.us/Tools/Stations/DAVDITCO', 'DAVDITCO']
# ['https://dwr.state.co.us/Tools/Stations/DAVDOWCO', 'DAVDOWCO']
# ['https://dwr.state.co.us/Tools/Stations/DC2DITCO', 'DC2DITCO']
# ['https://dwr.state.co.us/Tools/Stations/DCDDITCO', 'DCDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/DD3AUGCO', 'DD3AUGCO']
# ['https://dwr.state.co.us/Tools/Stations/DEADDPCO', 'DEADDPCO']
# ['https://dwr.state.co.us/Tools/Stations/DEDCRECO', 'DEDCRECO']
# ['https://dwr.state.co.us/Tools/Stations/DEDMOUCO', 'DEDMOUCO']
# ['https://dwr.state.co.us/Tools/Stations/DEERCKCO', 'DEERCKCO']
# ['https://dwr.state.co.us/Tools/Stations/DELDITCO', 'DELDITCO']
# ['https://dwr.state.co.us/Tools/Stations/DENTAYCO', 'DENTAYCO']
# ['https://dwr.state.co.us/Tools/Stations/DEUDITCO', 'DEUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/DILTUNCO', 'DILTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/DIXCOMCO', 'DIXCOMCO']
# ['https://dwr.state.co.us/Tools/Stations/DLFCMBCO', 'DLFCMBCO']
# ['https://dwr.state.co.us/Tools/Stations/DLFDT1CO', 'DLFDT1CO']
# ['https://dwr.state.co.us/Tools/Stations/DLFDT2CO', 'DLFDT2CO']
# ['https://dwr.state.co.us/Tools/Stations/DOLBMCCO', 'DOLBMCCO']
# ['https://dwr.state.co.us/Tools/Stations/DOLTUNCO', 'DOLTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/DORYINCO', 'DORYINCO']
# ['https://dwr.state.co.us/Tools/Stations/DOUOUTCO', 'DOUOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/DOVCANCO', 'DOVCANCO']
# ['https://dwr.state.co.us/Tools/Stations/DOZOUTCO', 'DOZOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/DRGDITCO', 'DRGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/DRYCARCO', 'DRYCARCO']
# ['https://dwr.state.co.us/Tools/Stations/DRYCRKCO', 'DRYCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/DRYRTNCO', 'DRYRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/DURPIPCO', 'DURPIPCO']
# ['https://dwr.state.co.us/Tools/Stations/DV2ADHOC', 'DV2ADHOC']
# ['https://dwr.state.co.us/Tools/Stations/DV7ADHOC', 'DV7ADHOC']
# ['https://dwr.state.co.us/Tools/Stations/DWRDECCO', 'DWRDECCO']
# ['https://dwr.state.co.us/Tools/Stations/EABBYPCO', 'EABBYPCO']
# ['https://dwr.state.co.us/Tools/Stations/EABDITCO', 'EABDITCO']
# ['https://dwr.state.co.us/Tools/Stations/EAGDITCO', 'EAGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/EASAPACO', 'EASAPACO']
# ['https://dwr.state.co.us/Tools/Stations/EASINLET', 'EASINLET']
# ['https://dwr.state.co.us/Tools/Stations/EASTCNCO', 'EASTCNCO']
# ['https://dwr.state.co.us/Tools/Stations/EG1DITCO', 'EG1DITCO']
# ['https://dwr.state.co.us/Tools/Stations/EG4FDRCO', 'EG4FDRCO']
# ['https://dwr.state.co.us/Tools/Stations/ELACASCO', 'ELACASCO']
# ['https://dwr.state.co.us/Tools/Stations/ELBCASCO', 'ELBCASCO']
# ['https://dwr.state.co.us/Tools/Stations/ELKCRKCO', 'ELKCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/ELVDITCO', 'ELVDITCO']
# ['https://dwr.state.co.us/Tools/Stations/EMPCANCO', 'EMPCANCO']
# ['https://dwr.state.co.us/Tools/Stations/EMPINLCO', 'EMPINLCO']
# ['https://dwr.state.co.us/Tools/Stations/ENPDITCO', 'ENPDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ENPLATCO', 'ENPLATCO']
# ['https://dwr.state.co.us/Tools/Stations/ENTDITCO', 'ENTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ERGGINCO', 'ERGGINCO']
# ['https://dwr.state.co.us/Tools/Stations/ERGOUTCO', 'ERGOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/ERGPINCO', 'ERGPINCO']
# ['https://dwr.state.co.us/Tools/Stations/ERIRGRCO', 'ERIRGRCO']
# ['https://dwr.state.co.us/Tools/Stations/EURDITCO', 'EURDITCO']
# ['https://dwr.state.co.us/Tools/Stations/EV1OUTCO', 'EV1OUTCO']
# ['https://dwr.state.co.us/Tools/Stations/EVADITCO', 'EVADITCO']
# ['https://dwr.state.co.us/Tools/Stations/EVANS2CO', 'EVANS2CO']
# ['https://dwr.state.co.us/Tools/Stations/EVRBYPCO', 'EVRBYPCO']
# ['https://dwr.state.co.us/Tools/Stations/EVRWATCO', 'EVRWATCO']
# ['https://dwr.state.co.us/Tools/Stations/EWIDITCO', 'EWIDITCO']
# ['https://dwr.state.co.us/Tools/Stations/EXLCANCO', 'EXLCANCO']
# ['https://dwr.state.co.us/Tools/Stations/FAIRVWCO', 'FAIRVWCO']
# ['https://dwr.state.co.us/Tools/Stations/FALIDACO', 'FALIDACO']
# ['https://dwr.state.co.us/Tools/Stations/FALOUTCO', 'FALOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/FARCANCO', 'FARCANCO']
# ['https://dwr.state.co.us/Tools/Stations/FARDITCO', 'FARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FARDTACO', 'FARDTACO']
# ['https://dwr.state.co.us/Tools/Stations/FARHLGCO', 'FARHLGCO']
# ['https://dwr.state.co.us/Tools/Stations/FARMERCO', 'FARMERCO']
# ['https://dwr.state.co.us/Tools/Stations/FHLARVCO', 'FHLARVCO']
# ['https://dwr.state.co.us/Tools/Stations/FHLAUGCO', 'FHLAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/FHLDITCO', 'FHLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FHLRALCO', 'FHLRALCO']
# ['https://dwr.state.co.us/Tools/Stations/FHLSTACO', 'FHLSTACO']
# ['https://dwr.state.co.us/Tools/Stations/FIDTAICO', 'FIDTAICO']
# ['https://dwr.state.co.us/Tools/Stations/FISCOPCO', 'FISCOPCO']
# ['https://dwr.state.co.us/Tools/Stations/FISDITCO', 'FISDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FISHESCO', 'FISHESCO']
# ['https://dwr.state.co.us/Tools/Stations/FISHLOCO', 'FISHLOCO']
# ['https://dwr.state.co.us/Tools/Stations/FISRTNCO', 'FISRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/FLOALECO', 'FLOALECO']
# ['https://dwr.state.co.us/Tools/Stations/FLOBLECO', 'FLOBLECO']
# ['https://dwr.state.co.us/Tools/Stations/FLOBONCO', 'FLOBONCO']
# ['https://dwr.state.co.us/Tools/Stations/FLOCANCO', 'FLOCANCO']
# ['https://dwr.state.co.us/Tools/Stations/FLOFARCO', 'FLOFARCO']
# ['https://dwr.state.co.us/Tools/Stations/FLSCANCO', 'FLSCANCO']
# ['https://dwr.state.co.us/Tools/Stations/FLYAUGCO', 'FLYAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/FLYCANCO', 'FLYCANCO']
# ['https://dwr.state.co.us/Tools/Stations/FOMDITCO', 'FOMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FOSOUTCO', 'FOSOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/FOU8THCO', 'FOU8THCO']
# ['https://dwr.state.co.us/Tools/Stations/FOUBERCO', 'FOUBERCO']
# ['https://dwr.state.co.us/Tools/Stations/FOUHARCO', 'FOUHARCO']
# ['https://dwr.state.co.us/Tools/Stations/FOUHIGCO', 'FOUHIGCO']
# ['https://dwr.state.co.us/Tools/Stations/FOUMORCO', 'FOUMORCO']
# ['https://dwr.state.co.us/Tools/Stations/FOUMOUCO', 'FOUMOUCO']
# ['https://dwr.state.co.us/Tools/Stations/FRAGRACO', 'FRAGRACO']
# ['https://dwr.state.co.us/Tools/Stations/FRAJDICO', 'FRAJDICO']
# ['https://dwr.state.co.us/Tools/Stations/FRAJIMCO', 'FRAJIMCO']
# ['https://dwr.state.co.us/Tools/Stations/FRAWNDCO', 'FRAWNDCO']
# ['https://dwr.state.co.us/Tools/Stations/FRAWPOCO', 'FRAWPOCO']
# ['https://dwr.state.co.us/Tools/Stations/FRDSEPCO', 'FRDSEPCO']
# ['https://dwr.state.co.us/Tools/Stations/FREDITCO', 'FREDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FRMDITCO', 'FRMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FRNCRKCO', 'FRNCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/FRYIVLCO', 'FRYIVLCO']
# ['https://dwr.state.co.us/Tools/Stations/FRYMERCO', 'FRYMERCO']
# ['https://dwr.state.co.us/Tools/Stations/FRYNFNCO', 'FRYNFNCO']
# ['https://dwr.state.co.us/Tools/Stations/FRYSFUCO', 'FRYSFUCO']
# ['https://dwr.state.co.us/Tools/Stations/FRYTHOCO', 'FRYTHOCO']
# ['https://dwr.state.co.us/Tools/Stations/FTBAUGCO', 'FTBAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/FTBDITCO', 'FTBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FUL3HGCO', 'FUL3HGCO']
# ['https://dwr.state.co.us/Tools/Stations/FUL3RTCO', 'FUL3RTCO']
# ['https://dwr.state.co.us/Tools/Stations/FULDITCO', 'FULDITCO']
# ['https://dwr.state.co.us/Tools/Stations/FULRTNCO', 'FULRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/GABDITCO', 'GABDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GACBFLCO', 'GACBFLCO']
# ['https://dwr.state.co.us/Tools/Stations/GALGALNM', 'GALGALNM']
# ['https://dwr.state.co.us/Tools/Stations/GARNETCO', 'GARNETCO']
# ['https://dwr.state.co.us/Tools/Stations/GARVILCO', 'GARVILCO']
# ['https://dwr.state.co.us/Tools/Stations/GDHDITCO', 'GDHDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GDNEMSCO', 'GDNEMSCO']
# ['https://dwr.state.co.us/Tools/Stations/GDNNPFCO', 'GDNNPFCO']
# ['https://dwr.state.co.us/Tools/Stations/GDNNPPCO', 'GDNNPPCO']
# ['https://dwr.state.co.us/Tools/Stations/GDNRWSCO', 'GDNRWSCO']
# ['https://dwr.state.co.us/Tools/Stations/GDRDITCO', 'GDRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GENMPLCO', 'GENMPLCO']
# ['https://dwr.state.co.us/Tools/Stations/GERDITCO', 'GERDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GHICANC2', 'GHICANC2']
# ['https://dwr.state.co.us/Tools/Stations/GHICANCO', 'GHICANCO']
# ['https://dwr.state.co.us/Tools/Stations/GICAGECO', 'GICAGECO']
# ['https://dwr.state.co.us/Tools/Stations/GICAGWCO', 'GICAGWCO']
# ['https://dwr.state.co.us/Tools/Stations/GNLKSPCO', 'GNLKSPCO']
# ['https://dwr.state.co.us/Tools/Stations/GODHSSCO', 'GODHSSCO']
# ['https://dwr.state.co.us/Tools/Stations/GODIT1CO', 'GODIT1CO']
# ['https://dwr.state.co.us/Tools/Stations/GOMDITCO', 'GOMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GOMRETCO', 'GOMRETCO']
# ['https://dwr.state.co.us/Tools/Stations/GOOHUMCO', 'GOOHUMCO']
# ['https://dwr.state.co.us/Tools/Stations/GOOPLMCO', 'GOOPLMCO']
# ['https://dwr.state.co.us/Tools/Stations/GOOWAGCO', 'GOOWAGCO']
# ['https://dwr.state.co.us/Tools/Stations/GORMINCO', 'GORMINCO']
# ['https://dwr.state.co.us/Tools/Stations/GOVDRACO', 'GOVDRACO']
# ['https://dwr.state.co.us/Tools/Stations/GRABDWCO', 'GRABDWCO']
# ['https://dwr.state.co.us/Tools/Stations/GRABUFCO', 'GRABUFCO']
# ['https://dwr.state.co.us/Tools/Stations/GRABWCCO', 'GRABWCCO']
# ['https://dwr.state.co.us/Tools/Stations/GRAWESCO', 'GRAWESCO']
# ['https://dwr.state.co.us/Tools/Stations/GRDVALCO', 'GRDVALCO']
# ['https://dwr.state.co.us/Tools/Stations/GREBYPCO', 'GREBYPCO']
# ['https://dwr.state.co.us/Tools/Stations/GRECRCCO', 'GRECRCCO']
# ['https://dwr.state.co.us/Tools/Stations/GRECRKCO', 'GRECRKCO']
# ['https://dwr.state.co.us/Tools/Stations/GRELOVCO', 'GRELOVCO']
# ['https://dwr.state.co.us/Tools/Stations/GREWASCO', 'GREWASCO']
# ['https://dwr.state.co.us/Tools/Stations/GRJWATCO', 'GRJWATCO']
# ['https://dwr.state.co.us/Tools/Stations/GRMDITCO', 'GRMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GRNDITCO', 'GRNDITCO']
# ['https://dwr.state.co.us/Tools/Stations/GRNDRDCO', 'GRNDRDCO']
# ['https://dwr.state.co.us/Tools/Stations/GRNRTNCO', 'GRNRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/GROBGRCO', 'GROBGRCO']
# ['https://dwr.state.co.us/Tools/Stations/GRSVALCO', 'GRSVALCO']
# ['https://dwr.state.co.us/Tools/Stations/GUAINFCO', 'GUAINFCO']
# ['https://dwr.state.co.us/Tools/Stations/GUAOUTCO', 'GUAOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/GUMCLRCO', 'GUMCLRCO']
# ['https://dwr.state.co.us/Tools/Stations/GUNREDCO', 'GUNREDCO']
# ['https://dwr.state.co.us/Tools/Stations/GYCROHCO', 'GYCROHCO']
# ['https://dwr.state.co.us/Tools/Stations/HABREDCO', 'HABREDCO']
# ['https://dwr.state.co.us/Tools/Stations/HANDITCO', 'HANDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HARDITCO', 'HARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HARDT2CO', 'HARDT2CO']
# ['https://dwr.state.co.us/Tools/Stations/HARPOTCO', 'HARPOTCO']
# ['https://dwr.state.co.us/Tools/Stations/HARRISON', 'HARRISON']
# ['https://dwr.state.co.us/Tools/Stations/HAYDITCO', 'HAYDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HAYREDCO', 'HAYREDCO']
# ['https://dwr.state.co.us/Tools/Stations/HENDITCO', 'HENDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HENOUTCO', 'HENOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/HENRESCO', 'HENRESCO']
# ['https://dwr.state.co.us/Tools/Stations/HENTESCO', 'HENTESCO']
# ['https://dwr.state.co.us/Tools/Stations/HFC930CO', 'HFC930CO']
# ['https://dwr.state.co.us/Tools/Stations/HFCBBSCO', 'HFCBBSCO']
# ['https://dwr.state.co.us/Tools/Stations/HFCCCRCO', 'HFCCCRCO']
# ['https://dwr.state.co.us/Tools/Stations/HFCFLTCO', 'HFCFLTCO']
# ['https://dwr.state.co.us/Tools/Stations/HFCLOVCO', 'HFCLOVCO']
# ['https://dwr.state.co.us/Tools/Stations/HFCPPLCO', 'HFCPPLCO']
# ['https://dwr.state.co.us/Tools/Stations/HFCWASCO', 'HFCWASCO']
# ['https://dwr.state.co.us/Tools/Stations/HGRMDWCO', 'HGRMDWCO']
# ['https://dwr.state.co.us/Tools/Stations/HIBDITCO', 'HIBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HIGHLDCO', 'HIGHLDCO']
# ['https://dwr.state.co.us/Tools/Stations/HILCANCO', 'HILCANCO']
# ['https://dwr.state.co.us/Tools/Stations/HILDITCO', 'HILDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HILNCNCO', 'HILNCNCO']
# ['https://dwr.state.co.us/Tools/Stations/HLDBBRCO', 'HLDBBRCO']
# ['https://dwr.state.co.us/Tools/Stations/HLNCANCO', 'HLNCANCO']
# ['https://dwr.state.co.us/Tools/Stations/HOCMINCO', 'HOCMINCO']
# ['https://dwr.state.co.us/Tools/Stations/HODDITCO', 'HODDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HOEDITCO', 'HOEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HOLCANCO', 'HOLCANCO']
# ['https://dwr.state.co.us/Tools/Stations/HOLINFCO', 'HOLINFCO']
# ['https://dwr.state.co.us/Tools/Stations/HOLOUTCO', 'HOLOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/HOMDITCO', 'HOMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HOMOTECO', 'HOMOTECO']
# ['https://dwr.state.co.us/Tools/Stations/HOMOUTCO', 'HOMOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/HOMRESCO', 'HOMRESCO']
# ['https://dwr.state.co.us/Tools/Stations/HOMSPACO', 'HOMSPACO']
# ['https://dwr.state.co.us/Tools/Stations/HOMSPICO', 'HOMSPICO']
# ['https://dwr.state.co.us/Tools/Stations/HOMSPRCO', 'HOMSPRCO']
# ['https://dwr.state.co.us/Tools/Stations/HOMTUNCO', 'HOMTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/HONDITCO', 'HONDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HOROUTCO', 'HOROUTCO']
# ['https://dwr.state.co.us/Tools/Stations/HORTOOCO', 'HORTOOCO']
# ['https://dwr.state.co.us/Tools/Stations/HOSDITCO', 'HOSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HOWDITCO', 'HOWDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HP1OUTCO', 'HP1OUTCO']
# ['https://dwr.state.co.us/Tools/Stations/HPQDITCO', 'HPQDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HRC194CO', 'HRC194CO']
# ['https://dwr.state.co.us/Tools/Stations/HRDIT2CO', 'HRDIT2CO']
# ['https://dwr.state.co.us/Tools/Stations/HRLAUGCO', 'HRLAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/HRRDITCO', 'HRRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HRUAUGCO', 'HRUAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/HSCCLPCO', 'HSCCLPCO']
# ['https://dwr.state.co.us/Tools/Stations/HSCPVDCO', 'HSCPVDCO']
# ['https://dwr.state.co.us/Tools/Stations/HSPTUNCO', 'HSPTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/HUDDITCO', 'HUDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/HUEBADCO', 'HUEBADCO']
# ['https://dwr.state.co.us/Tools/Stations/HUEBAMCO', 'HUEBAMCO']
# ['https://dwr.state.co.us/Tools/Stations/HUEDYLCO', 'HUEDYLCO']
# ['https://dwr.state.co.us/Tools/Stations/HUEI25CO', 'HUEI25CO']
# ['https://dwr.state.co.us/Tools/Stations/HURREDCO', 'HURREDCO']
# ['https://dwr.state.co.us/Tools/Stations/HYDDITCO', 'HYDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/IDACRKCO', 'IDACRKCO']
# ['https://dwr.state.co.us/Tools/Stations/ILLDITCO', 'ILLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ILLRANCO', 'ILLRANCO']
# ['https://dwr.state.co.us/Tools/Stations/ILLRTNCO', 'ILLRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/IPVDITCO', 'IPVDITCO']
# ['https://dwr.state.co.us/Tools/Stations/IPVDT2CO', 'IPVDT2CO']
# ['https://dwr.state.co.us/Tools/Stations/IRNSTNCO', 'IRNSTNCO']
# ['https://dwr.state.co.us/Tools/Stations/IVAOUTCO', 'IVAOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/IVCRNACO', 'IVCRNACO']
# ['https://dwr.state.co.us/Tools/Stations/JACCANCO', 'JACCANCO']
# ['https://dwr.state.co.us/Tools/Stations/JACDITCO', 'JACDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JACKLACO', 'JACKLACO']
# ['https://dwr.state.co.us/Tools/Stations/JACO10CO', 'JACO10CO']
# ['https://dwr.state.co.us/Tools/Stations/JACUPPCO', 'JACUPPCO']
# ['https://dwr.state.co.us/Tools/Stations/JAKDITCO', 'JAKDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JAMDITCO', 'JAMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JAYTOMCO', 'JAYTOMCO']
# ['https://dwr.state.co.us/Tools/Stations/JBCDITCO', 'JBCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JBRINLCO', 'JBRINLCO']
# ['https://dwr.state.co.us/Tools/Stations/JBROUTCO', 'JBROUTCO']
# ['https://dwr.state.co.us/Tools/Stations/JBS186CO', 'JBS186CO']
# ['https://dwr.state.co.us/Tools/Stations/JDFDITCO', 'JDFDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JEFBELCO', 'JEFBELCO']
# ['https://dwr.state.co.us/Tools/Stations/JEFJEFCO', 'JEFJEFCO']
# ['https://dwr.state.co.us/Tools/Stations/JEFSNYCO', 'JEFSNYCO']
# ['https://dwr.state.co.us/Tools/Stations/JEMBELNM', 'JEMBELNM']
# ['https://dwr.state.co.us/Tools/Stations/JNEDITCO', 'JNEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JODDITCO', 'JODDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JOHDITCO', 'JOHDITCO']
# ['https://dwr.state.co.us/Tools/Stations/JONESDCO', 'JONESDCO']
# ['https://dwr.state.co.us/Tools/Stations/JULRETCO', 'JULRETCO']
# ['https://dwr.state.co.us/Tools/Stations/JUMINLCO', 'JUMINLCO']
# ['https://dwr.state.co.us/Tools/Stations/JUNLRGCO', 'JUNLRGCO']
# ['https://dwr.state.co.us/Tools/Stations/JWCCHACO', 'JWCCHACO']
# ['https://dwr.state.co.us/Tools/Stations/KANJUNCO', 'KANJUNCO']
# ['https://dwr.state.co.us/Tools/Stations/KENINLCO', 'KENINLCO']
# ['https://dwr.state.co.us/Tools/Stations/KERDITCO', 'KERDITCO']
# ['https://dwr.state.co.us/Tools/Stations/KERRTNCO', 'KERRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/KERSHTCO', 'KERSHTCO']
# ['https://dwr.state.co.us/Tools/Stations/KERVILCO', 'KERVILCO']
# ['https://dwr.state.co.us/Tools/Stations/KISCRKCO', 'KISCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/KKBCANCO', 'KKBCANCO']
# ['https://dwr.state.co.us/Tools/Stations/KMLOUTCO', 'KMLOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/KMLPINCO', 'KMLPINCO']
# ['https://dwr.state.co.us/Tools/Stations/LACDITCO', 'LACDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LAGLAGCO', 'LAGLAGCO']
# ['https://dwr.state.co.us/Tools/Stations/LAJCAPCO', 'LAJCAPCO']
# ['https://dwr.state.co.us/Tools/Stations/LAKATLCO', 'LAKATLCO']
# ['https://dwr.state.co.us/Tools/Stations/LAKBTLCO', 'LAKBTLCO']
# ['https://dwr.state.co.us/Tools/Stations/LAMCANCO', 'LAMCANCO']
# ['https://dwr.state.co.us/Tools/Stations/LAPBRECO', 'LAPBRECO']
# ['https://dwr.state.co.us/Tools/Stations/LAPCHECO', 'LAPCHECO']
# ['https://dwr.state.co.us/Tools/Stations/LAPHESCO', 'LAPHESCO']
# ['https://dwr.state.co.us/Tools/Stations/LAPLODCO', 'LAPLODCO']
# ['https://dwr.state.co.us/Tools/Stations/LAPLONCO', 'LAPLONCO']
# ['https://dwr.state.co.us/Tools/Stations/LAPMEXCO', 'LAPMEXCO']
# ['https://dwr.state.co.us/Tools/Stations/LAPTUNCO', 'LAPTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/LARDITCO', 'LARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LARNO2CO', 'LARNO2CO']
# ['https://dwr.state.co.us/Tools/Stations/LARRIVCO', 'LARRIVCO']
# ['https://dwr.state.co.us/Tools/Stations/LASDITCO', 'LASDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LAWAUGCO', 'LAWAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/LAWIRRCO', 'LAWIRRCO']
# ['https://dwr.state.co.us/Tools/Stations/LBBINLCO', 'LBBINLCO']
# ['https://dwr.state.co.us/Tools/Stations/LBBOUTCO', 'LBBOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/LC2DITCO', 'LC2DITCO']
# ['https://dwr.state.co.us/Tools/Stations/LC2SPRCO', 'LC2SPRCO']
# ['https://dwr.state.co.us/Tools/Stations/LCCWSCCO', 'LCCWSCCO']
# ['https://dwr.state.co.us/Tools/Stations/LCPUMPCO', 'LCPUMPCO']
# ['https://dwr.state.co.us/Tools/Stations/LCWDITCO', 'LCWDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LEEBAUCO', 'LEEBAUCO']
# ['https://dwr.state.co.us/Tools/Stations/LEFCRECO', 'LEFCRECO']
# ['https://dwr.state.co.us/Tools/Stations/LEFTHDCO', 'LEFTHDCO']
# ['https://dwr.state.co.us/Tools/Stations/LEGDITCO', 'LEGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LELAHICO', 'LELAHICO']
# ['https://dwr.state.co.us/Tools/Stations/LEWDITCO', 'LEWDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LF4DIVCO', 'LF4DIVCO']
# ['https://dwr.state.co.us/Tools/Stations/LFCBSLCO', 'LFCBSLCO']
# ['https://dwr.state.co.us/Tools/Stations/LGRRTNCO', 'LGRRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/LHDDITCO', 'LHDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LIDDITCO', 'LIDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LITCANCO', 'LITCANCO']
# ['https://dwr.state.co.us/Tools/Stations/LITDRYCO', 'LITDRYCO']
# ['https://dwr.state.co.us/Tools/Stations/LITOSOCO', 'LITOSOCO']
# ['https://dwr.state.co.us/Tools/Stations/LITSPGCO', 'LITSPGCO']
# ['https://dwr.state.co.us/Tools/Stations/LITTH1CO', 'LITTH1CO']
# ['https://dwr.state.co.us/Tools/Stations/LITTH2CO', 'LITTH2CO']
# ['https://dwr.state.co.us/Tools/Stations/LKCTURCO', 'LKCTURCO']
# ['https://dwr.state.co.us/Tools/Stations/LLABY2CO', 'LLABY2CO']
# ['https://dwr.state.co.us/Tools/Stations/LLABYPCO', 'LLABYPCO']
# ['https://dwr.state.co.us/Tools/Stations/LLADIVCO', 'LLADIVCO']
# ['https://dwr.state.co.us/Tools/Stations/LLPRETCO', 'LLPRETCO']
# ['https://dwr.state.co.us/Tools/Stations/LMCDITCO', 'LMCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LNBC10CO', 'LNBC10CO']
# ['https://dwr.state.co.us/Tools/Stations/LODPOLCO', 'LODPOLCO']
# ['https://dwr.state.co.us/Tools/Stations/LOLRTNCO', 'LOLRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/LOMOUTCO', 'LOMOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/LONALOCO', 'LONALOCO']
# ['https://dwr.state.co.us/Tools/Stations/LONBLOCO', 'LONBLOCO']
# ['https://dwr.state.co.us/Tools/Stations/LONBUFCO', 'LONBUFCO']
# ['https://dwr.state.co.us/Tools/Stations/LONCARCO', 'LONCARCO']
# ['https://dwr.state.co.us/Tools/Stations/LONMINCO', 'LONMINCO']
# ['https://dwr.state.co.us/Tools/Stations/LONREDCO', 'LONREDCO']
# ['https://dwr.state.co.us/Tools/Stations/LONSUPCO', 'LONSUPCO']
# ['https://dwr.state.co.us/Tools/Stations/LOPLABCO', 'LOPLABCO']
# ['https://dwr.state.co.us/Tools/Stations/LOSODVCO', 'LOSODVCO']
# ['https://dwr.state.co.us/Tools/Stations/LOSORTCO', 'LOSORTCO']
# ['https://dwr.state.co.us/Tools/Stations/LOUDITCO', 'LOUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LOUTCNCO', 'LOUTCNCO']
# ['https://dwr.state.co.us/Tools/Stations/LOVSKICO', 'LOVSKICO']
# ['https://dwr.state.co.us/Tools/Stations/LOWDITCO', 'LOWDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LPBDITCO', 'LPBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LPBEASCO', 'LPBEASCO']
# ['https://dwr.state.co.us/Tools/Stations/LPBWESCO', 'LPBWESCO']
# ['https://dwr.state.co.us/Tools/Stations/LPCDITCO', 'LPCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LPIRDICO', 'LPIRDICO']
# ['https://dwr.state.co.us/Tools/Stations/LRASMICO', 'LRASMICO']
# ['https://dwr.state.co.us/Tools/Stations/LSEDITCO', 'LSEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/LSRDIXWY', 'LSRDIXWY']
# ['https://dwr.state.co.us/Tools/Stations/LTCANYCO', 'LTCANYCO']
# ['https://dwr.state.co.us/Tools/Stations/LTCDITCO', 'LTCDITCO']
# ...
# ['https://dwr.state.co.us/Tools/Stations/RMTDITCO', 'RMTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/RMTRTNCO', 'RMTRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/RNJDITCO', 'RNJDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ROAFRYCO', 'ROAFRYCO']
# ['https://dwr.state.co.us/Tools/Stations/ROAMILCO', 'ROAMILCO']
# ['https://dwr.state.co.us/Tools/Stations/ROBTUNCO', 'ROBTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/ROMDITCO', 'ROMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ROSRTNCO', 'ROSRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/ROUDELCO', 'ROUDELCO']
# ['https://dwr.state.co.us/Tools/Stations/ROUREACO', 'ROUREACO']
# ['https://dwr.state.co.us/Tools/Stations/RRCCPLCO', 'RRCCPLCO']
# ['https://dwr.state.co.us/Tools/Stations/RULTOOCO', 'RULTOOCO']
# ['https://dwr.state.co.us/Tools/Stations/RUNYONCO', 'RUNYONCO']
# ['https://dwr.state.co.us/Tools/Stations/RURDITCO', 'RURDITCO']
# ['https://dwr.state.co.us/Tools/Stations/RUTAILCO', 'RUTAILCO']
# ['https://dwr.state.co.us/Tools/Stations/RYADITCO', 'RYADITCO']
# ['https://dwr.state.co.us/Tools/Stations/SAFDELCO', 'SAFDELCO']
# ['https://dwr.state.co.us/Tools/Stations/SAFUPPCO', 'SAFUPPCO']
# ['https://dwr.state.co.us/Tools/Stations/SAGCEMCO', 'SAGCEMCO']
# ['https://dwr.state.co.us/Tools/Stations/SAGSAGCO', 'SAGSAGCO']
# ['https://dwr.state.co.us/Tools/Stations/SALTMOCO', 'SALTMOCO']
# ['https://dwr.state.co.us/Tools/Stations/SALTOXCO', 'SALTOXCO']
# ['https://dwr.state.co.us/Tools/Stations/SANCRECO', 'SANCRECO']
# ['https://dwr.state.co.us/Tools/Stations/SANCRKCO', 'SANCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/SANDUNCO', 'SANDUNCO']
# ['https://dwr.state.co.us/Tools/Stations/SANESPCO', 'SANESPCO']
# ['https://dwr.state.co.us/Tools/Stations/SANFTGCO', 'SANFTGCO']
# ['https://dwr.state.co.us/Tools/Stations/SANMANCO', 'SANMANCO']
# ['https://dwr.state.co.us/Tools/Stations/SANORTCO', 'SANORTCO']
# ['https://dwr.state.co.us/Tools/Stations/SAPSAPCO', 'SAPSAPCO']
# ['https://dwr.state.co.us/Tools/Stations/SARKMOCO', 'SARKMOCO']
# ['https://dwr.state.co.us/Tools/Stations/SATCEDCO', 'SATCEDCO']
# ['https://dwr.state.co.us/Tools/Stations/SBBDITCO', 'SBBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SBCDITCO', 'SBCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SBCHOWCO', 'SBCHOWCO']
# ['https://dwr.state.co.us/Tools/Stations/SBRSTVCO', 'SBRSTVCO']
# ['https://dwr.state.co.us/Tools/Stations/SCHFLMCO', 'SCHFLMCO']
# ['https://dwr.state.co.us/Tools/Stations/SCPOUTCO', 'SCPOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/SCPXINCO', 'SCPXINCO']
# ['https://dwr.state.co.us/Tools/Stations/SCRDITCO', 'SCRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SDRDITCO', 'SDRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SEC3RTCO', 'SEC3RTCO']
# ['https://dwr.state.co.us/Tools/Stations/SECDITCO', 'SECDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SELGCNCO', 'SELGCNCO']
# ['https://dwr.state.co.us/Tools/Stations/SETDITCO', 'SETDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SFKANTCO', 'SFKANTCO']
# ['https://dwr.state.co.us/Tools/Stations/SFLDITCO', 'SFLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SFWBUDCO', 'SFWBUDCO']
# ['https://dwr.state.co.us/Tools/Stations/SHLINLCO', 'SHLINLCO']
# ['https://dwr.state.co.us/Tools/Stations/SHLLMOCO', 'SHLLMOCO']
# ['https://dwr.state.co.us/Tools/Stations/SHLOUTCO', 'SHLOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/SHRDITCO', 'SHRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SIGDITCO', 'SIGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SILDITCO', 'SILDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SKGOUTCO', 'SKGOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/SKYDCLCO', 'SKYDCLCO']
# ['https://dwr.state.co.us/Tools/Stations/SLGAUGCO', 'SLGAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/SLTDITCO', 'SLTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SLUDITCO', 'SLUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SLVCANCO', 'SLVCANCO']
# ['https://dwr.state.co.us/Tools/Stations/SMEDITCO', 'SMEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SMEMDICO', 'SMEMDICO']
# ['https://dwr.state.co.us/Tools/Stations/SMGDITCO', 'SMGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SNAKEYCO', 'SNAKEYCO']
# ['https://dwr.state.co.us/Tools/Stations/SNOCRECO', 'SNOCRECO']
# ['https://dwr.state.co.us/Tools/Stations/SOAKNBCO', 'SOAKNBCO']
# ['https://dwr.state.co.us/Tools/Stations/SOAKTECO', 'SOAKTECO']
# ['https://dwr.state.co.us/Tools/Stations/SOARGRCO', 'SOARGRCO']
# ['https://dwr.state.co.us/Tools/Stations/SOARSACO', 'SOARSACO']
# ['https://dwr.state.co.us/Tools/Stations/SOBOELCO', 'SOBOELCO']
# ['https://dwr.state.co.us/Tools/Stations/SOCAMECO', 'SOCAMECO']
# ['https://dwr.state.co.us/Tools/Stations/SOCLACCO', 'SOCLACCO']
# ['https://dwr.state.co.us/Tools/Stations/SOCOUTCO', 'SOCOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/SOCWCRCO', 'SOCWCRCO']
# ['https://dwr.state.co.us/Tools/Stations/SODA15CO', 'SODA15CO']
# ['https://dwr.state.co.us/Tools/Stations/SODAINCO', 'SODAINCO']
# ['https://dwr.state.co.us/Tools/Stations/SODATCCO', 'SODATCCO']
# ['https://dwr.state.co.us/Tools/Stations/SOSDITCO', 'SOSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SOUCANCO', 'SOUCANCO']
# ['https://dwr.state.co.us/Tools/Stations/SOUCOLCO', 'SOUCOLCO']
# ['https://dwr.state.co.us/Tools/Stations/SOUCRECO', 'SOUCRECO']
# ['https://dwr.state.co.us/Tools/Stations/SOUDITCO', 'SOUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SOULASCO', 'SOULASCO']
# ['https://dwr.state.co.us/Tools/Stations/SPACRECO', 'SPACRECO']
# ['https://dwr.state.co.us/Tools/Stations/SPCDITCO', 'SPCDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SPJVHGCO', 'SPJVHGCO']
# ['https://dwr.state.co.us/Tools/Stations/SPJVRFCO', 'SPJVRFCO']
# ['https://dwr.state.co.us/Tools/Stations/SPJVRPCO', 'SPJVRPCO']
# ['https://dwr.state.co.us/Tools/Stations/SPLDITCO', 'SPLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SPPUMPCO', 'SPPUMPCO']
# ['https://dwr.state.co.us/Tools/Stations/SPRAUGCO', 'SPRAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/SPRBRNCO', 'SPRBRNCO']
# ['https://dwr.state.co.us/Tools/Stations/SPRDITCO', 'SPRDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SPRRETCO', 'SPRRETCO']
# ['https://dwr.state.co.us/Tools/Stations/SPSCFLCO', 'SPSCFLCO']
# ['https://dwr.state.co.us/Tools/Stations/SPSCSFCO', 'SPSCSFCO']
# ['https://dwr.state.co.us/Tools/Stations/SRNDITCO', 'SRNDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SSVWARCO', 'SSVWARCO']
# ['https://dwr.state.co.us/Tools/Stations/STALENCO', 'STALENCO']
# ['https://dwr.state.co.us/Tools/Stations/STCTUNCO', 'STCTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/STECANCO', 'STECANCO']
# ['https://dwr.state.co.us/Tools/Stations/STEDITCO', 'STEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/STLINECO', 'STLINECO']
# ['https://dwr.state.co.us/Tools/Stations/SUGARCCO', 'SUGARCCO']
# ['https://dwr.state.co.us/Tools/Stations/SUPDITCO', 'SUPDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SVCBSBCO', 'SVCBSBCO']
# ['https://dwr.state.co.us/Tools/Stations/SVCHGICO', 'SVCHGICO']
# ['https://dwr.state.co.us/Tools/Stations/SVCHYGCO', 'SVCHYGCO']
# ['https://dwr.state.co.us/Tools/Stations/SVCLOPCO', 'SVCLOPCO']
# ['https://dwr.state.co.us/Tools/Stations/SVCLYOCO', 'SVCLYOCO']
# ['https://dwr.state.co.us/Tools/Stations/SVCPLACO', 'SVCPLACO']
# ['https://dwr.state.co.us/Tools/Stations/SVLONGCO', 'SVLONGCO']
# ['https://dwr.state.co.us/Tools/Stations/SVPPRTCO', 'SVPPRTCO']
# ['https://dwr.state.co.us/Tools/Stations/SVSCARCO', 'SVSCARCO']
# ['https://dwr.state.co.us/Tools/Stations/SVSHERCO', 'SVSHERCO']
# ['https://dwr.state.co.us/Tools/Stations/SVSLT1CO', 'SVSLT1CO']
# ['https://dwr.state.co.us/Tools/Stations/SVSLT2CO', 'SVSLT2CO']
# ['https://dwr.state.co.us/Tools/Stations/SVSLYOCO', 'SVSLYOCO']
# ['https://dwr.state.co.us/Tools/Stations/SVSSUPCO', 'SVSSUPCO']
# ['https://dwr.state.co.us/Tools/Stations/SWADITCO', 'SWADITCO']
# ['https://dwr.state.co.us/Tools/Stations/SWEDITCO', 'SWEDITCO']
# ['https://dwr.state.co.us/Tools/Stations/SWLDITCO', 'SWLDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TABDITCO', 'TABDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TACODICO', 'TACODICO']
# ['https://dwr.state.co.us/Tools/Stations/TAGDITCO', 'TAGDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TARBELCO', 'TARBELCO']
# ['https://dwr.state.co.us/Tools/Stations/TARBORCO', 'TARBORCO']
# ['https://dwr.state.co.us/Tools/Stations/TARCOMCO', 'TARCOMCO']
# ['https://dwr.state.co.us/Tools/Stations/TARTARCO', 'TARTARCO']
# ['https://dwr.state.co.us/Tools/Stations/TCBWTCCO', 'TCBWTCCO']
# ['https://dwr.state.co.us/Tools/Stations/TCCKTCCO', 'TCCKTCCO']
# ['https://dwr.state.co.us/Tools/Stations/TERCANCO', 'TERCANCO']
# ['https://dwr.state.co.us/Tools/Stations/TETDITCO', 'TETDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TH17RNCO', 'TH17RNCO']
# ['https://dwr.state.co.us/Tools/Stations/THOMUPCO', 'THOMUPCO']
# ['https://dwr.state.co.us/Tools/Stations/THRNCKCO', 'THRNCKCO']
# ['https://dwr.state.co.us/Tools/Stations/THURINCO', 'THURINCO']
# ['https://dwr.state.co.us/Tools/Stations/TLMTCKCO', 'TLMTCKCO']
# ['https://dwr.state.co.us/Tools/Stations/TNGCRKCO', 'TNGCRKCO']
# ['https://dwr.state.co.us/Tools/Stations/TOMCRECO', 'TOMCRECO']
# ['https://dwr.state.co.us/Tools/Stations/TOMDITCO', 'TOMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TOMMYDCO', 'TOMMYDCO']
# ['https://dwr.state.co.us/Tools/Stations/TOWCANCO', 'TOWCANCO']
# ['https://dwr.state.co.us/Tools/Stations/TOWEASCO', 'TOWEASCO']
# ['https://dwr.state.co.us/Tools/Stations/TOWWESCO', 'TOWWESCO']
# ['https://dwr.state.co.us/Tools/Stations/TRADITCO', 'TRADITCO']
# ['https://dwr.state.co.us/Tools/Stations/TREDITCO', 'TREDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TRIMTNCO', 'TRIMTNCO']
# ['https://dwr.state.co.us/Tools/Stations/TRISEYCO', 'TRISEYCO']
# ['https://dwr.state.co.us/Tools/Stations/TRISMICO', 'TRISMICO']
# ['https://dwr.state.co.us/Tools/Stations/TRITURCO', 'TRITURCO']
# ['https://dwr.state.co.us/Tools/Stations/TRMDITCO', 'TRMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TROGARCO', 'TROGARCO']
# ['https://dwr.state.co.us/Tools/Stations/TROKRECO', 'TROKRECO']
# ['https://dwr.state.co.us/Tools/Stations/TROUTDWN', 'TROUTDWN']
# ['https://dwr.state.co.us/Tools/Stations/TRUDITCO', 'TRUDITCO']
# ['https://dwr.state.co.us/Tools/Stations/TURECGCO', 'TURECGCO']
# ['https://dwr.state.co.us/Tools/Stations/TWITUNCO', 'TWITUNCO']
# ['https://dwr.state.co.us/Tools/Stations/UAUGRTCO', 'UAUGRTCO']
# ['https://dwr.state.co.us/Tools/Stations/UCANALCO', 'UCANALCO']
# ['https://dwr.state.co.us/Tools/Stations/UNCBRGCO', 'UNCBRGCO']
# ['https://dwr.state.co.us/Tools/Stations/UNCOLACO', 'UNCOLACO']
# ['https://dwr.state.co.us/Tools/Stations/UNCUPSCO', 'UNCUPSCO']
# ['https://dwr.state.co.us/Tools/Stations/UNIDITCO', 'UNIDITCO']
# ['https://dwr.state.co.us/Tools/Stations/UNIFDRCO', 'UNIFDRCO']
# ['https://dwr.state.co.us/Tools/Stations/UNION2CO', 'UNION2CO']
# ['https://dwr.state.co.us/Tools/Stations/UNIRESCO', 'UNIRESCO']
# ['https://dwr.state.co.us/Tools/Stations/UNISRNCO', 'UNISRNCO']
# ['https://dwr.state.co.us/Tools/Stations/UPBDITCO', 'UPBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/UPBVCRCO', 'UPBVCRCO']
# ['https://dwr.state.co.us/Tools/Stations/UTEFTGCO', 'UTEFTGCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTCQLCO', 'UVTCQLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTECNCO', 'UVTECNCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTFGLCO', 'UVTFGLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTFLLCO', 'UVTFLLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTFNLCO', 'UVTFNLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTFQLCO', 'UVTFQLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTFVLCO', 'UVTFVLCO']
# ['https://dwr.state.co.us/Tools/Stations/UVTMDCCO', 'UVTMDCCO']
# ['https://dwr.state.co.us/Tools/Stations/VALDITCO', 'VALDITCO']
# ['https://dwr.state.co.us/Tools/Stations/VASCANCO', 'VASCANCO']
# ['https://dwr.state.co.us/Tools/Stations/VASQD1CO', 'VASQD1CO']
# ['https://dwr.state.co.us/Tools/Stations/VASQD2CO', 'VASQD2CO']
# ['https://dwr.state.co.us/Tools/Stations/VASQD3CO', 'VASQD3CO']
# ['https://dwr.state.co.us/Tools/Stations/VENSANCO', 'VENSANCO']
# ['https://dwr.state.co.us/Tools/Stations/VIDLERCO', 'VIDLERCO']
# ['https://dwr.state.co.us/Tools/Stations/VIDTUNCO', 'VIDTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/VOSDITCO', 'VOSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WANAUGCO', 'WANAUGCO']
# ['https://dwr.state.co.us/Tools/Stations/WANDITCO', 'WANDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WARDBCCO', 'WARDBCCO']
# ['https://dwr.state.co.us/Tools/Stations/WARDCCCO', 'WARDCCCO']
# ['https://dwr.state.co.us/Tools/Stations/WARDITCO', 'WARDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WCLOUTCO', 'WCLOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/WCOBMRCO', 'WCOBMRCO']
# ['https://dwr.state.co.us/Tools/Stations/WCSDITCO', 'WCSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WDSDITCO', 'WDSDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WDSSUBCO', 'WDSSUBCO']
# ['https://dwr.state.co.us/Tools/Stations/WDVDITCO', 'WDVDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WEBDITCO', 'WEBDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WELDCOCO', 'WELDCOCO']
# ['https://dwr.state.co.us/Tools/Stations/WELDITCO', 'WELDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WELRETCO', 'WELRETCO']
# ['https://dwr.state.co.us/Tools/Stations/WEMDITCO', 'WEMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WESDITCO', 'WESDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WESRIFCO', 'WESRIFCO']
# ['https://dwr.state.co.us/Tools/Stations/WESSEPCO', 'WESSEPCO']
# ['https://dwr.state.co.us/Tools/Stations/WFKCROCO', 'WFKCROCO']
# ['https://dwr.state.co.us/Tools/Stations/WFKMOUCO', 'WFKMOUCO']
# ['https://dwr.state.co.us/Tools/Stations/WGLINLCO', 'WGLINLCO']
# ['https://dwr.state.co.us/Tools/Stations/WGPBPFCO', 'WGPBPFCO']
# ['https://dwr.state.co.us/Tools/Stations/WGPPMPCO', 'WGPPMPCO']
# ['https://dwr.state.co.us/Tools/Stations/WHIBUFCO', 'WHIBUFCO']
# ['https://dwr.state.co.us/Tools/Stations/WHITNYCO', 'WHITNYCO']
# ['https://dwr.state.co.us/Tools/Stations/WHWRTNCO', 'WHWRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/WILABVCO', 'WILABVCO']
# ['https://dwr.state.co.us/Tools/Stations/WILBSLCO', 'WILBSLCO']
# ['https://dwr.state.co.us/Tools/Stations/WILCANCO', 'WILCANCO']
# ['https://dwr.state.co.us/Tools/Stations/WILCRDCO', 'WILCRDCO']
# ['https://dwr.state.co.us/Tools/Stations/WILCRECO', 'WILCRECO']
# ['https://dwr.state.co.us/Tools/Stations/WILDBYCO', 'WILDBYCO']
# ['https://dwr.state.co.us/Tools/Stations/WILDINCO', 'WILDINCO']
# ['https://dwr.state.co.us/Tools/Stations/WILHERNM', 'WILHERNM']
# ['https://dwr.state.co.us/Tools/Stations/WINBYPCO', 'WINBYPCO']
# ['https://dwr.state.co.us/Tools/Stations/WINDESCO', 'WINDESCO']
# ['https://dwr.state.co.us/Tools/Stations/WINRIVCO', 'WINRIVCO']
# ['https://dwr.state.co.us/Tools/Stations/WLFDITCO', 'WLFDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WLMDITCO', 'WLMDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WLMTALCO', 'WLMTALCO']
# ['https://dwr.state.co.us/Tools/Stations/WLTDITCO', 'WLTDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WLTNCKCO', 'WLTNCKCO']
# ['https://dwr.state.co.us/Tools/Stations/WMFKMHCO', 'WMFKMHCO']
# ['https://dwr.state.co.us/Tools/Stations/WRDDITCO', 'WRDDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WSDEARCO', 'WSDEARCO']
# ['https://dwr.state.co.us/Tools/Stations/WSDRAVCO', 'WSDRAVCO']
# ['https://dwr.state.co.us/Tools/Stations/WSTRTLCO', 'WSTRTLCO']
# ['https://dwr.state.co.us/Tools/Stations/WSTTUNCO', 'WSTTUNCO']
# ['https://dwr.state.co.us/Tools/Stations/WURDITCO', 'WURDITCO']
# ['https://dwr.state.co.us/Tools/Stations/WUREXDCO', 'WUREXDCO']
# ['https://dwr.state.co.us/Tools/Stations/WUREXTCO', 'WUREXTCO']
# ['https://dwr.state.co.us/Tools/Stations/WVHRTNCO', 'WVHRTNCO']
# ['https://dwr.state.co.us/Tools/Stations/WWSCURCO', 'WWSCURCO']
# ['https://dwr.state.co.us/Tools/Stations/YAMABCAT', 'YAMABCAT']
# ['https://dwr.state.co.us/Tools/Stations/YAMABVCO', 'YAMABVCO']
# ['https://dwr.state.co.us/Tools/Stations/YAMBELCO', 'YAMBELCO']
# ['https://dwr.state.co.us/Tools/Stations/YAMOUTCO', 'YAMOUTCO']
# ['https://dwr.state.co.us/Tools/Stations/YAMYAMCO', 'YAMYAMCO']
# ['https://dwr.state.co.us/Tools/Stations/YOXDITCO', 'YOXDITCO']
# ['https://dwr.state.co.us/Tools/Stations/ZWETURCO', 'ZWETURCO']
# id and name fields populated

# %%
# Confirm unique ID in identifier field
# Field to check for uniqueness
field_name = "id"

# Use a set to keep track of unique values encountered in the field
unique_values = set()

# Initialize a counter to keep track of the total number of rows
total_rows = 0

# Initialize a flag to check for spaces
has_spaces = False

# Start a search cursor to iterate through the rows and check for unique values and spaces
with arcpy.da.UpdateCursor(CO_gage, field_name) as cursor:
    for row in cursor:
        total_rows += 1
        value = row[0]
        if value in unique_values:
            print(f"Non-unique value found: {value}")
        else:
            unique_values.add(value)

        if " " in value:
            has_spaces = True
            # Replace spaces with "-"
            row[0] = value.replace(" ", "-")
            cursor.updateRow(row)

# Check if the number of unique values is the same as the total number of rows
if len(unique_values) == total_rows:
    print("All values in the 'Identifier' field are unique.")
else:
    print("There are duplicate values in the 'Identifier' field.")

# Check if there are any spaces in the 'Identifier' field
if has_spaces:
    print("There were spaces in the 'Identifier' field. They have been replaced with '-'.")
else:
    print("No spaces found in the 'Identifier' field.")
# Out:
# Non-unique value found: 6200561A
# Non-unique value found: CLFOFDCO
# Non-unique value found: MICDCPCO
# There are duplicate values in the 'Identifier' field.
# No spaces found in the 'Identifier' field.

# %%
# Select values from non unique idenfiers above 
values_to_select = ["6200561A", "CLFOFDCO", "MICDCPCO"]

# Create a SQL query for the 'name' field using the IN operator
# This will select features where the 'name' field matches any of the specified values
query = f"name IN {tuple(values_to_select)}"

# Select features based on the SQL query
arcpy.management.SelectLayerByAttribute(CO_gage, "NEW_SELECTION", query)
#noting there are 6 values, 2 duplicates of each above

print("Investigate the values to see which should be removed")
# Out:
# Investigate the values to see which should be removed

# %%
# Clear Selection
arcpy.management.SelectLayerByAttribute(CO_gage, "CLEAR_SELECTION")
# Out:
# <Result 'CO_gages_final'>

# %%
# re select values to select for the first criteria
values_to_select_1 = ["6200561A", "CLFOFDCO", "MICDCPCO"]

# Create a SQL query for the 'name' field using the IN operator
query_1 = f"name IN {tuple(values_to_select_1)}"

# specify values to select for the second criteria
values_to_select_2 = ["JOE WRIGHT CREEK", "COW CREEK", "BASIN CREEK"]

# Create a SQL query for the 'Water_Source' field using the IN operator
query_2 = f"Water_Source IN {tuple(values_to_select_2)}"

# Combine the two queries using the AND operator
combined_query = f"({query_1}) AND ({query_2})"

# Select features based on the combined query
arcpy.management.SelectLayerByAttribute(CO_gage, "NEW_SELECTION", combined_query)


print("Selection should result in 3 rows")
print("STOP and confirm you want to move on and delete")
# Out:
# Selection should result in 3 rows
# STOP and confirm you want to move on and delete

# %%
# Delete the selected features
arcpy.management.DeleteFeatures(CO_gage)

# Clear the selection
arcpy.management.SelectLayerByAttribute(CO_gage, "CLEAR_SELECTION")
print("Now duplicates are removed")
# Out:
# Now duplicates are removed

# %%
# Delete records with no lat/long
# SQL query to select features where Latitude and Longitude are both null
query = "Latitude IS NULL AND Longitude IS NULL"

# Select features based on the SQL query
arcpy.management.SelectLayerByAttribute(CO_gage, "NEW_SELECTION", query)

print("Selected rows with no lat and long values")
# Out:
# Selected rows with no lat and long values

# %%
# Delete the selected rows
arcpy.management.DeleteRows(CO_gage)

# Clear the selection
arcpy.management.SelectLayerByAttribute(CO_gage, "CLEAR_SELECTION")
print("Rows with no lat/long deleted")
# Out:
# Rows with no lat/long deleted

# %%
#Update Fields

arcpy.CalculateField_management(CO_gage, "provider_name", "'Colorado Decision Support System'")
arcpy.CalculateField_management(CO_gage, "provider_url", '"{}"'.format('"!More_Information!"'), "PYTHON3")
arcpy.CalculateField_management(CO_gage, "provider_id", '"{}"'.format('"!id!"'), "PYTHON3")
arcpy.CalculateField_management(CO_gage, "provider_code", "'cdss'")

print("Fields calculated")
# Out:
# Fields calculated

# %%
#tcreate url
codeblock = """
def url_join(*parts: list) -> str:
    return '/'.join([str(p).strip().strip('/') for p in parts])
"""
##geoconnex.us/cdss/gages/id

expression = """url_join("https://geoconnex.us/cdss/gages", !id!)"""
arcpy.management.CalculateField(CO_gage, "uri", expression, "PYTHON3", codeblock)
print("uri calculated")
# Out:
# uri calculated

# %% [markdown]
# ### CSV download table is not available for Colorado gages. Created a fake table for now:

# %%
import pandas as pd

#create fake table manually from this exported excel
arcpy.conversion.TableToExcel(CO_gage, r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_gage.xlsx")

#Created fake table 
# Path to the CSV file
csv_file_path = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\Temp_List.csv"
pd.set_option('display.width', 1000)


# Read the CSV file into a pandas DataFrame


df = pd.read_csv(csv_file_path, skiprows=[0])


# Display the first few rows of the data frame to verify the data
print(df.head())
df.columns = df.columns.str.replace(' ', '_')
print(df.columns)
# Out:
#                     Data Set Id        ID  ...  Value  Status
# 0                  GARNET CANAL      7805  ...    NaN     NaN
# 1  ANTELOPE BEACH RECHARGE AREA  0101794A  ...    NaN     NaN
# 2        UNITED #3 PUMP INLET 1  0200616A  ...    NaN     NaN
# 3        UNITED #3 PUMP INLET 2  0200619A  ...    NaN     NaN
# 4     FULTON UNITED AUG STATION  0202990A  ...    NaN     NaN
#
# [5 rows x 8 columns]
# Index(['Data_Set_Id', 'ID', 'Location', 'Location_Folder', 'Start_of_Record', 'End_of_Record', 'Value', 'Status'], dtype='object')

# %% [markdown]
# #### Need both unique ID and the location name in the fake table ^^^

# %%
# Perform the field calculations on the pandas DataFrame
df["location_id"] = df['Data_Set_Id'].str.replace(r".*@", "", regex=True)
df["about_uri"] = "https://geoconnex.us/cdss/gages/" + df["ID"]
df["data_set_type"] = df["Data_Set_Id"].str.replace(r"@.*", "", regex=True)
df["data_set_path"] = df["data_set_type"].str.replace(".", "/", 1)

#update format: https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=7805&measTypes=Streamflow
df["url"] = "https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=" + df["ID"] + "&measTypes=Streamflow"

df["provider_code"] = "cdss"
df["parameter_name"] = df["data_set_type"]
df["parameter_group"] = "discharge"
df["parameter_id"] = df["provider_code"] + "-" + df["parameter_group"]
df["about_uri"] = df["about_uri"]
df["name"] = df["Data_Set_Id"]

print("Complete")
# Out:
# Complete

# %%
df.head()
# Out:
#                     Data_Set_Id  ...                          name
# 0                  GARNET CANAL  ...                  GARNET CANAL
# 1  ANTELOPE BEACH RECHARGE AREA  ...  ANTELOPE BEACH RECHARGE AREA
# 2        UNITED #3 PUMP INLET 1  ...        UNITED #3 PUMP INLET 1
# 3        UNITED #3 PUMP INLET 2  ...        UNITED #3 PUMP INLET 2
# 4     FULTON UNITED AUG STATION  ...     FULTON UNITED AUG STATION
#
# [5 rows x 18 columns]

# %%
# Print the first five rows of the "data_set_url" column
pd.options.display.max_colwidth = 300
print(df["url"].head())
# Out:
# 0        https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=7805&measTypes=Streamflow
# 1    https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=0101794A&measTypes=Streamflow
# 2    https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=0200616A&measTypes=Streamflow
# 3    https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=0200619A&measTypes=Streamflow
# 4    https://dwr.state.co.us/Tools/Stations/ExportAnlTsFileResult?station_num=0202990A&measTypes=Streamflow
# Name: url, dtype: object

# %%
#Perform final field calculations on pandas DataFrame

end_df = df[["about_uri", "url", "name", "provider_code", "parameter_id", "parameter_name", "parameter_group"]]
end_df.head()
end_df.to_csv("C:\\Users\\ewiggans\\Desktop\\GeoConnexMap\\ColoradoGage\\CO_download_table.csv")
#Export and write to new CSV

# %%
import json
import requests
from shapely.geometry import shape, Point

def get_comid_intersect(geom):
    # Convert the input geom to GeoJSON using Shapely
    point = Point(geom)

    # Convert the Point to GeoJSON
    geom_geojson = shape(point).__geo_interface__

    url = 'https://nhdpv2-census.internetofwater.app/collections/2020/items?filter-lang=cql-json'
    filter_ = {
        'intersects': [
            {'property': 'shape'},
            geom_geojson  # Use the Shapely-converted GeoJSON
        ]
    }
    headers = {
        'Content-Type': 'application/query-cql-json'
    }
    r = requests.post(url, headers=headers, json=filter_)
    fc = r.json()
    if 'features' in fc and len(fc['features']) > 0:
        feature = fc['features'][0]
        return feature['properties']['featureid']
    else:
        return None

# Update Cursor
with arcpy.da.UpdateCursor(CO_gage, ["Shape", "comid"]) as cursor:
    for row in cursor:
        geom = row[0]
        comid = get_comid_intersect(geom)
        if comid is not None:
            print(comid, end='\r', flush=True)
            row[1] = comid
            cursor.updateRow(row)


print("comid calculated")
# Out:
# comid calculated

# %%
# Read in the CSV file as a geodatabase table
csv_table = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\nhdpv2_lookup.csv"
csv_table_name = "NHDPV2_Lookup"
arcpy.TableToTable_conversion(csv_table, arcpy.env.workspace, csv_table_name)

# Add a new field 'comid_text' to the CSV table with a data type of TEXT
arcpy.AddField_management(csv_table_name, "comid_text", "TEXT")

# Calculate the 'comid_text' field by copying the values from the 'comid' field
expression = "!comid!"
codeblock = ""
arcpy.CalculateField_management(csv_table_name, "comid_text", expression, "PYTHON3", codeblock)

print("Added 'comid_text' field and set its values equal to 'comid' as text.")
# Out:
# Added 'comid_text' field and set its values equal to 'comid' as text.

# %%
# Join the CSV table to the CO gage feature class based on the "comid" field
arcpy.AddJoin_management(CO_gage, "comid", csv_table_name, "comid_text", "KEEP_COMMON")

# Calculate the "mainstem_uri" field to be equal to the "uri" field in the CSV table
expression = "!{}.uri!".format(csv_table_name)
arcpy.CalculateField_management(CO_gage, "mainstem_uri", expression, "PYTHON3")

# Remove the join to the CSV table
arcpy.RemoveJoin_management(CO_gage, csv_table_name)
# Out:
# <Result 'CO_gages_final'>

# %%
# Define the output GeoJSON file path
output_geojson_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_gages.geojson"

# #set projection to wgs84
# arcpy.management.DefineProjection(
#     in_dataset="CO_gages_final",
#     coor_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]'
# )


# Export the feature class to GeoJSON
arcpy.FeaturesToJSON_conversion(in_features = CO_gage, 
                                out_json_file = output_geojson_file,
                                geoJSON = "GEOJSON")


print(f"Exported {CO_gage} to {output_geojson_file} in GeoJSON format.")
# Out:
# Exported CO_gages_final to C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_gages.geojson in GeoJSON format.

# %%
import geopandas as gpd

def group_data(gdf, gpkg_file, csv_file):
    # Make mapping dictionary
    mapping = {}
    df = pd.read_csv(csv_file)
    for index, row in df.iterrows():
        location = row['about_uri']
        data = row.drop(['about_uri'])
        if location not in mapping:
            mapping[location] = []
        mapping[location].append(data.to_dict())
    # Apply mapping
    for index, row in gdf.iterrows():
        location = row['uri']
        if location in mapping:
            gdf.at[index, 'data'] = \
                json.dumps(mapping[location])
    gdf.to_file(gpkg_file, driver="GPKG")

gdf = gpd.read_file(r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_gages.geojson")
csv_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_download_table.csv"
gpkg_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\ColoradoGage\CO_gages.gpkg"
group_data(gdf, gpkg_file, csv_file)
print("Complete")
# Out:
# Complete
