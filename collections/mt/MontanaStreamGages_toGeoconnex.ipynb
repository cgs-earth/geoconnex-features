# %% [markdown]
# ## Translate Montana (MT) stream gage data into Geoconnex

# %% [markdown]
# Sources are: https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/0 for the locations, for which copy features is performed and https://gis.dnrc.mt.gov/apps/stage/gage-report/ and for data

# %%
import arcpy

# Set the workspace environment
arcpy.env.workspace = r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb"

# reassign variable name
MT_gage = "MT_gages"

# Define a list of field names and their types
field_list = [
    ("uri", "TEXT"),
    ("name", "TEXT"),
    ("id", "TEXT"),
    ("provider_name", "TEXT"),
    ("provider_id", "TEXT"),
    ("provider_url", "TEXT"),
    ("provider_code", "TEXT"),
    ("mainstem_uri", "TEXT"),
    ("comid", "TEXT")
]

# Add the new fields using a loop
for field_name, field_type in field_list:
    arcpy.AddField_management(MT_gage, field_name, field_type)

# Confirm the field addition
field_names = [field.name for field in arcpy.ListFields(MT_gage)]
print("Fields in the layer after addition:", field_names)
# Out:
# Fields in the layer after addition: ['OBJECTID', 'Shape', 'LocationID', 'LocationCode', 'LocationName', 'LocationPath', 'LocationType', 'IsExternalLocation', 'Longitude', 'Latitude', 'UtcOffset', 'LastModified', 'ElevationUnits', 'Elevation', 'Description', 'Tags', 'ExtendedAttributeValues', 'StatusDesc', 'ActiveFlag', 'CountyName', 'BasinName', 'HUC8Code', 'uri', 'name', 'id', 'provider_name', 'provider_id', 'provider_url', 'provider_code', 'mainstem_uri', 'comid']

# %%
## Get unique ID, which comes from Site_Name

# Create an update cursor to iterate through the rows
with arcpy.da.UpdateCursor(MT_gage, ['LocationCode', 'id']) as cursor:
    for row in cursor:
        # Get the Site_Name value
        site_name = row[0]

        # Remove spaces and assign the result to the 'id' field
        row[1] = site_name.replace(" ", "")

        # Update the row
        cursor.updateRow(row)

# Clean up the cursor
del cursor

# Set name = id
# Define the expression for the field calculation
expression = "!id!"  # Set the 'name' field equal to the 'id' field

# Perform the field calculation
arcpy.management.CalculateField(MT_gage, "name", expression, "PYTHON3")

print("id and name fields populated")
# Out:
# id and name fields populated

# %%
# Confirm unique ID in identifier field
# Field to check for uniqueness
field_name = "id"

# Use a set to keep track of unique values encountered in the field
unique_values = set()

# Initialize a counter to keep track of the total number of rows
total_rows = 0

# Initialize a flag to check for spaces
has_spaces = False

# Start a search cursor to iterate through the rows and check for unique values and spaces
with arcpy.da.UpdateCursor(MT_gage, field_name) as cursor:
    for row in cursor:
        total_rows += 1
        value = row[0]
        if value in unique_values:
            print(f"Non-unique value found: {value}")
        else:
            unique_values.add(value)

        if " " in value:
            has_spaces = True
            # Replace spaces with "-"
            row[0] = value.replace(" ", "-")
            cursor.updateRow(row)

# Check if the number of unique values is the same as the total number of rows
if len(unique_values) == total_rows:
    print("All values in the 'Identifier' field are unique.")
else:
    print("There are duplicate values in the 'Identifier' field.")

# Check if there are any spaces in the 'Identifier' field
if has_spaces:
    print("There were spaces in the 'Identifier' field. They have been replaced with '-'.")
else:
    print("No spaces found in the 'Identifier' field.")
# Out:
# All values in the 'Identifier' field are unique.
# No spaces found in the 'Identifier' field.

# %%
#Update Fields

arcpy.CalculateField_management(MT_gage, "provider_name", "'Montana Department of Natural Resources and Conservation'")
#Updated to Montana
arcpy.CalculateField_management(MT_gage, "provider_url", '"https://gis.dnrc.mt.gov/apps/stage/"', "PYTHON3")
arcpy.CalculateField_management(MT_gage, "provider_id", '"{}"'.format('"!id!"'), "PYTHON3")
arcpy.CalculateField_management(MT_gage, "provider_code", "'mtdnrc'")

print("Fields calculated")
# Out:
# Fields calculated

# %%
#create url
codeblock = """
def url_join(*parts: list) -> str:
    return '/'.join([str(p).strip().strip('/') for p in parts])
"""
##geoconnex.us/ndwr/gages/id

expression = """url_join("https://geoconnex.us/mtdnrc/gages", !id!)"""
arcpy.management.CalculateField(MT_gage, "uri", expression, "PYTHON3", codeblock)
print("uri calculated")
# Out:
# uri calculated

# %% [markdown]
# ### Read in data table from https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3 service for secondary data table

# %%
import requests
import pandas as pd
# Define the URL of the REST API endpoint
url = "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query"
# Define the parameters for your request
params = {
    "where": "1=1",  # This is a simple query to get all records
    "outFields": "*",  # This will include all fields in the response
    "f": "json",  # You can request data in JSON format
}
# Make a GET request to the API
response = requests.get(url, params=params)
# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    # Extract the features from the response
    features = [v['attributes'] for v in data['features']]

    df = pd.json_normalize(features)
        
    # Specify the full path for saving the CSV file
    save_path = r'C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_stations_data.csv'
      
    # Save the DataFrame to the specified CSV file
    df.to_csv(save_path, index=False)
    print(f"Data downloaded and saved as '{save_path}'")
else:
    print("Failed to retrieve data. Status code:", response.status_code)
# Out:
# Data downloaded and saved as 'C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_stations_data.csv'

# %%
df.head()
# Out:
#    OBJECTID  ... ParameterLabel
# 0       473  ...      Discharge
# 1       489  ...      Discharge
# 2       505  ...          Stage
# 3       521  ...          Stage
# 4       537  ...      Discharge
#
# [5 rows x 20 columns]

# %%
# Assuming you have already loaded data into the DataFrame 'df'

#get unique ids for the site name from location code, but remove spaces
df['Site_name'] = df['LocationCode']
# Remove spaces in the "Site_name" field
df['Site_name'] = df['Site_name'].str.replace(' ', '')
# this is where I need to check 
df["about_uri"] = "https://geoconnex.us/mtdnrc/gages/" + df['Site_name']

# # Update format of Montana gages using a lambda function
df["url"] = df["SensorCode"].apply(lambda x: f"https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='{x.replace(' ', '+')}'")

#Calculate other fields 
df["provider_code"] = "mtdnrc"
df["name"] = df["SensorCode"]
df["parameter_id"] = df["provider_code"] + "-" + df["ParameterLabel"]
df["parameter_name"] = df['SensorCode'].str.split('@').str[0]
df["parameter_group"] = df["ParameterLabel"]

print("Complete")
# Out:
# Complete

# %%
df.head()
# Out:
#    OBJECTID  ... parameter_group
# 0       473  ...       Discharge
# 1       489  ...       Discharge
# 2       505  ...           Stage
# 3       521  ...           Stage
# 4       537  ...       Discharge
#
# [5 rows x 28 columns]

# %%
# Print the first five rows of the "data_set_url" column
pd.options.display.max_colwidth = 300
print(df["url"].head())
# Out:
# 0    https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@40A+4080'
# 1        https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.discharge@40A+9000'
# 2              https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working@41K+4000'
# 3          https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working-old@41H+2000'
# 4    https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@76E+3000'
# Name: url, dtype: object

# %%
#Perform final field calculations on pandas DataFrame

end_df = df[["about_uri", "url", "name", "provider_code", "parameter_id", "parameter_name", "parameter_group"]]
end_df.head()
end_df.to_csv("C:\\Users\\ewiggans\\Desktop\\GeoConnexMap\\MontanaGage\\MT_download_table.csv")
#Export and write to new CSV
print("Exported to csv")
# Out:
# Exported to csv

# %% [markdown]
# ### Perform final calculations and exports

# %%
import json
import requests
from shapely.geometry import shape, Point


def get_comid_intersect(geom):
    # Convert the input geom to GeoJSON using Shapely
    point = Point(geom)

    # Convert the Point to GeoJSON
    geom_geojson = shape(point).__geo_interface__

    url = 'https://nhdpv2-census.internetofwater.app/collections/2020/items?filter-lang=cql-json'
    filter_ = {
        'intersects': [
            {'property': 'shape'},
            geom_geojson  # Use the Shapely-converted GeoJSON
        ]
    }
    headers = {
        'Content-Type': 'application/query-cql-json'
    }
    r = requests.post(url, headers=headers, json=filter_)
    fc = r.json()
    if 'features' in fc and len(fc['features']) > 0:
        feature = fc['features'][0]
        return feature['properties']['featureid']
    else:
        return None

# Update Cursor
with arcpy.da.UpdateCursor(MT_gage, ["Shape", "comid"]) as cursor:
    for row in cursor:
        geom = row[0]
        comid = get_comid_intersect(geom)
        if comid is not None:
            print(comid, end='\r', flush=True)
            row[1] = comid
            cursor.updateRow(row)


print("comid calculated")
# Out:
# comid calculated

# %%
# Read in the CSV file as a geodatabase table
csv_table = r"C:\\Users\\ewiggans\\Desktop\\GeoConnexMap\\MontanaGage\\nhdpv2_lookup.csv"
csv_table_name = "NHDPV2_Lookup"
arcpy.TableToTable_conversion(csv_table, arcpy.env.workspace, csv_table_name)

# Add a new field 'comid_text' to the CSV table with a data type of TEXT
arcpy.AddField_management(csv_table_name, "comid_text", "TEXT")

# Calculate the 'comid_text' field by copying the values from the 'comid' field
expression = "!comid!"
codeblock = ""
arcpy.CalculateField_management(csv_table_name, "comid_text", expression, "PYTHON3", codeblock)

print("Added 'comid_text' field and set its values equal to 'comid' as text.")
# Out:
# Added 'comid_text' field and set its values equal to 'comid' as text.

# %%
# Join the CSV table to the MT gage feature class based on the "comid" field
arcpy.AddJoin_management(MT_gage, "comid", csv_table_name, "comid_text", "KEEP_COMMON")

# Calculate the "mainstem_uri" field to be equal to the "uri" field in the CSV table
expression = "!{}.uri!".format(csv_table_name)
arcpy.CalculateField_management(MT_gage, "mainstem_uri", expression, "PYTHON3")

# Remove the join to the CSV table
arcpy.RemoveJoin_management(MT_gage, csv_table_name)
print("Complete")
# Out:
# Complete

# %%
# Define the output GeoJSON file path
output_geojson_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_gages.geojson"

# Export the feature class to GeoJSON
arcpy.FeaturesToJSON_conversion(in_features = MT_gage, 
                                out_json_file = output_geojson_file,
                                geoJSON = "GEOJSON")
print(f"Exported {MT_gage} to {output_geojson_file} in GeoJSON format.")
# Out:
# Exported MT_gages to C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_gages.geojson in GeoJSON format.

# %%
import geopandas as gpd

def group_data(gdf, gpkg_file, csv_file):
    # Make mapping dictionary
    mapping = {}
    df = pd.read_csv(csv_file)
    for index, row in df.iterrows():
        location = row['about_uri']
        data = row.drop(['about_uri'])
        if location not in mapping:
            mapping[location] = []
        mapping[location].append(data.to_dict())
    #print(mapping)
    # Apply mapping
    for index, row in gdf.iterrows():
        location = row['uri']
        if location in mapping:
            gdf.at[index, 'data'] = \
                json.dumps(mapping[location])
     #   print(location)
    gdf.to_file(gpkg_file, driver="GPKG")

gdf = gpd.read_file(r"C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_gages.geojson")
csv_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_download_table.csv"
gpkg_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\MontanaGage\MT_gages.gpkg"
group_data(gdf, gpkg_file, csv_file)
print("Complete")
# Out:
# {'https://geoconnex.us/mtdnrc/gages/40A4080': [{'Unnamed: 0': 0, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@40A+4080'", 'name': 'Discharge.Daily Average@40A 4080', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.Daily Average', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 467, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.discharge@40A+4080'", 'name': 'Discharge.discharge@40A 4080', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.discharge', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 468, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working@40A+4080'", 'name': 'Stage.working@40A 4080', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Stage', 'parameter_name': 'Stage.working', 'parameter_group': 'Stage'}], 'https://geoconnex.us/mtdnrc/gages/40A9000': [{'Unnamed: 0': 1, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.discharge@40A+9000'", 'name': 'Discharge.discharge@40A 9000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.discharge', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 481, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@40A+9000'", 'name': 'Discharge.Daily Average@40A 9000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.Daily Average', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 496, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working@40A+9000'", 'name': 'Stage.working@40A 9000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Stage', 'parameter_name': 'Stage.working', 'parameter_group': 'Stage'}], 'https://geoconnex.us/mtdnrc/gages/41K4000': [{'Unnamed: 0': 2, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working@41K+4000'", 'name': 'Stage.working@41K 4000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Stage', 'parameter_name': 'Stage.working', 'parameter_group': 'Stage'}, {'Unnamed: 0': 509, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@41K+4000'", 'name': 'Discharge.Daily Average@41K 4000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.Daily Average', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 510, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.discharge@41K+4000'", 'name': 'Discharge.discharge@41K 4000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.discharge', 'parameter_group': 'Discharge'}], 'https://geoconnex.us/mtdnrc/gages/41H2000': [{'Unnamed: 0': 3, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Stage.working-old@41H+2000'", 'name': 'Stage.working-old@41H 2000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Stage', 'parameter_name': 'Stage.working-old', 'parameter_group': 'Stage'}, {'Unnamed: 0': 523, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.Daily+Average@41H+2000'", 'name': 'Discharge.Daily Average@41H 2000', 'provider_code': 'mtdnrc', 'parameter_id': 'mtdnrc-Discharge', 'parameter_name': 'Discharge.Daily Average', 'parameter_group': 'Discharge'}, {'Unnamed: 0': 524, 'url': "https://gis.dnrc.mt.gov/arcgis/rest/services/WRD/WMB_StAGE/MapServer/3/query?where=SensorCode='Discharge.discharge@41H+2000'", 'name': 'Discharge.discharge@41H 2000', 'provider_code':  ...
# https://geoconnex.us/mtdnrc/gages/40A10000
# https://geoconnex.us/mtdnrc/gages/40A1500
# https://geoconnex.us/mtdnrc/gages/40A2000
# https://geoconnex.us/mtdnrc/gages/40A3000
# https://geoconnex.us/mtdnrc/gages/40A4080
# https://geoconnex.us/mtdnrc/gages/40A5000
# https://geoconnex.us/mtdnrc/gages/40A7000
# https://geoconnex.us/mtdnrc/gages/40A8080
# https://geoconnex.us/mtdnrc/gages/40A8100
# https://geoconnex.us/mtdnrc/gages/40A9000
# https://geoconnex.us/mtdnrc/gages/40B06000
# https://geoconnex.us/mtdnrc/gages/40F00900
# https://geoconnex.us/mtdnrc/gages/40F01100
# https://geoconnex.us/mtdnrc/gages/40F01700
# https://geoconnex.us/mtdnrc/gages/40F01800
# https://geoconnex.us/mtdnrc/gages/40F01900
# https://geoconnex.us/mtdnrc/gages/40I10000
# https://geoconnex.us/mtdnrc/gages/40J08900
# https://geoconnex.us/mtdnrc/gages/40J09000
# https://geoconnex.us/mtdnrc/gages/40J09100
# https://geoconnex.us/mtdnrc/gages/40L-10050013
# https://geoconnex.us/mtdnrc/gages/40R05000
# https://geoconnex.us/mtdnrc/gages/41A02000
# https://geoconnex.us/mtdnrc/gages/41A03000
# https://geoconnex.us/mtdnrc/gages/41A04000
# https://geoconnex.us/mtdnrc/gages/41A04001
# https://geoconnex.us/mtdnrc/gages/41A04500
# https://geoconnex.us/mtdnrc/gages/41A05001
# https://geoconnex.us/mtdnrc/gages/41A06000
# https://geoconnex.us/mtdnrc/gages/41A07000
# https://geoconnex.us/mtdnrc/gages/41A07001
# https://geoconnex.us/mtdnrc/gages/41A08900
# https://geoconnex.us/mtdnrc/gages/41A10000
# https://geoconnex.us/mtdnrc/gages/41A10170
# https://geoconnex.us/mtdnrc/gages/41A10180
# https://geoconnex.us/mtdnrc/gages/41A11400
# https://geoconnex.us/mtdnrc/gages/41A11470
# https://geoconnex.us/mtdnrc/gages/41A11600
# https://geoconnex.us/mtdnrc/gages/41A11610
# https://geoconnex.us/mtdnrc/gages/41A11640
# https://geoconnex.us/mtdnrc/gages/41A11645
# https://geoconnex.us/mtdnrc/gages/41A11680
# https://geoconnex.us/mtdnrc/gages/41A11690
# https://geoconnex.us/mtdnrc/gages/41B16400
# https://geoconnex.us/mtdnrc/gages/41B16450
# https://geoconnex.us/mtdnrc/gages/41C04500
# https://geoconnex.us/mtdnrc/gages/41C04900
# https://geoconnex.us/mtdnrc/gages/41C05000
# https://geoconnex.us/mtdnrc/gages/41C07000
# https://geoconnex.us/mtdnrc/gages/41C08000
# https://geoconnex.us/mtdnrc/gages/41C09000
# https://geoconnex.us/mtdnrc/gages/41C19010
# https://geoconnex.us/mtdnrc/gages/41D01000
# https://geoconnex.us/mtdnrc/gages/41D02000
# https://geoconnex.us/mtdnrc/gages/41D03800
# https://geoconnex.us/mtdnrc/gages/41D04800
# https://geoconnex.us/mtdnrc/gages/41D05000
# https://geoconnex.us/mtdnrc/gages/41D06550
# https://geoconnex.us/mtdnrc/gages/41D06700
# https://geoconnex.us/mtdnrc/gages/41D06850
# https://geoconnex.us/mtdnrc/gages/41D06870
# https://geoconnex.us/mtdnrc/gages/41D07200
# https://geoconnex.us/mtdnrc/gages/41D07600
# https://geoconnex.us/mtdnrc/gages/41D07700
# https://geoconnex.us/mtdnrc/gages/41D07790
# https://geoconnex.us/mtdnrc/gages/41D07850
# https://geoconnex.us/mtdnrc/gages/41D07870
# https://geoconnex.us/mtdnrc/gages/41D07900
# https://geoconnex.us/mtdnrc/gages/41D08000
# https://geoconnex.us/mtdnrc/gages/41D08800
# https://geoconnex.us/mtdnrc/gages/41E33600
# https://geoconnex.us/mtdnrc/gages/41E33800
# https://geoconnex.us/mtdnrc/gages/41E33890
# https://geoconnex.us/mtdnrc/gages/41G26600
# https://geoconnex.us/mtdnrc/gages/41G28650
# https://geoconnex.us/mtdnrc/gages/41G29400
# https://geoconnex.us/mtdnrc/gages/41G29900
# https://geoconnex.us/mtdnrc/gages/41H08900
# https://geoconnex.us/mtdnrc/gages/41H08950
# https://geoconnex.us/mtdnrc/gages/41H08990
# https://geoconnex.us/mtdnrc/gages/41H1000
# https://geoconnex.us/mtdnrc/gages/41H1500
# https://geoconnex.us/mtdnrc/gages/41H2000
# https://geoconnex.us/mtdnrc/gages/41I01600
# https://geoconnex.us/mtdnrc/gages/41I02400
# https://geoconnex.us/mtdnrc/gages/41I03500
# https://geoconnex.us/mtdnrc/gages/41I06060
# https://geoconnex.us/mtdnrc/gages/41I1500
# https://geoconnex.us/mtdnrc/gages/41I2000
# https://geoconnex.us/mtdnrc/gages/41I3000
# https://geoconnex.us/mtdnrc/gages/41J01800
# https://geoconnex.us/mtdnrc/gages/41J05000
# https://geoconnex.us/mtdnrc/gages/41J06500
# https://geoconnex.us/mtdnrc/gages/41J08500
# https://geoconnex.us/mtdnrc/gages/41J09000
# https://geoconnex.us/mtdnrc/gages/41J09500
# https://geoconnex.us/mtdnrc/gages/41K09900
# https://geoconnex.us/mtdnrc/gages/41K2080
# https://geoconnex.us/mtdnrc/gages/41K4000
# https://geoconnex.us/mtdnrc/gages/41O02000
# https://geoconnex.us/mtdnrc/gages/41O02900
# https://geoconnex.us/mtdnrc/gages/41O03000
# https://geoconnex.us/mtdnrc/gages/41O03001
# https://geoconnex.us/mtdnrc/gages/41O04000
# https://geoconnex.us/mtdnrc/gages/41O04001
# https://geoconnex.us/mtdnrc/gages/41O04002
# https://geoconnex.us/mtdnrc/gages/41O04500
# https://geoconnex.us/mtdnrc/gages/41O04810
# https://geoconnex.us/mtdnrc/gages/41O04850
# https://geoconnex.us/mtdnrc/gages/41O04855
# https://geoconnex.us/mtdnrc/gages/41O04890
# https://geoconnex.us/mtdnrc/gages/41O04910
# https://geoconnex.us/mtdnrc/gages/41O04950
# https://geoconnex.us/mtdnrc/gages/41O04970
# https://geoconnex.us/mtdnrc/gages/41O04971
# https://geoconnex.us/mtdnrc/gages/41O04972
# https://geoconnex.us/mtdnrc/gages/41O04990
# https://geoconnex.us/mtdnrc/gages/41O04991
# https://geoconnex.us/mtdnrc/gages/41O04992
# https://geoconnex.us/mtdnrc/gages/41O05000
# https://geoconnex.us/mtdnrc/gages/41O06900
# https://geoconnex.us/mtdnrc/gages/41O07800
# https://geoconnex.us/mtdnrc/gages/41O08000
# https://geoconnex.us/mtdnrc/gages/41O08500
# https://geoconnex.us/mtdnrc/gages/41O09000
# https://geoconnex.us/mtdnrc/gages/41Q90595
# https://geoconnex.us/mtdnrc/gages/41S08700
# https://geoconnex.us/mtdnrc/gages/41S08900
# https://geoconnex.us/mtdnrc/gages/41S11350
# https://geoconnex.us/mtdnrc/gages/41S11380
# https://geoconnex.us/mtdnrc/gages/41S11400
# https://geoconnex.us/mtdnrc/gages/41S11500
# https://geoconnex.us/mtdnrc/gages/41S11690
# https://geoconnex.us/mtdnrc/gages/41S11750
# https://geoconnex.us/mtdnrc/gages/41S11760
# https://geoconnex.us/mtdnrc/gages/41S11790
# https://geoconnex.us/mtdnrc/gages/41S11805
# https://geoconnex.us/mtdnrc/gages/41S2080
# https://geoconnex.us/mtdnrc/gages/41S3000
# https://geoconnex.us/mtdnrc/gages/41U01000
# https://geoconnex.us/mtdnrc/gages/41U03900
# https://geoconnex.us/mtdnrc/gages/41U04000
# https://geoconnex.us/mtdnrc/gages/41U05900
# https://geoconnex.us/mtdnrc/gages/41U08100
# https://geoconnex.us/mtdnrc/gages/41U08900
# https://geoconnex.us/mtdnrc/gages/41U09000
# https://geoconnex.us/mtdnrc/gages/42B01900
# https://geoconnex.us/mtdnrc/gages/42C10000
# https://geoconnex.us/mtdnrc/gages/42C10100
# https://geoconnex.us/mtdnrc/gages/42C10200
# https://geoconnex.us/mtdnrc/gages/42C10300
# https://geoconnex.us/mtdnrc/gages/42KJ01010
# https://geoconnex.us/mtdnrc/gages/42KJ01050
# https://geoconnex.us/mtdnrc/gages/42KJ02000
# https://geoconnex.us/mtdnrc/gages/42KJ02050
# https://geoconnex.us/mtdnrc/gages/42M273754
# https://geoconnex.us/mtdnrc/gages/42M273796
# https://geoconnex.us/mtdnrc/gages/43A07100
# https://geoconnex.us/mtdnrc/gages/43A08100
# https://geoconnex.us/mtdnrc/gages/43A08200
# https://geoconnex.us/mtdnrc/gages/43A09000
# https://geoconnex.us/mtdnrc/gages/43A09250
# https://geoconnex.us/mtdnrc/gages/43A09500
# https://geoconnex.us/mtdnrc/gages/43B01990
# https://geoconnex.us/mtdnrc/gages/43B02950
# https://geoconnex.us/mtdnrc/gages/43B02990
# https://geoconnex.us/mtdnrc/gages/43B04000
# https://geoconnex.us/mtdnrc/gages/43B04010
# https://geoconnex.us/mtdnrc/gages/43B04040
# https://geoconnex.us/mtdnrc/gages/43B04050
# https://geoconnex.us/mtdnrc/gages/43B05000
# https://geoconnex.us/mtdnrc/gages/43B05280
# https://geoconnex.us/mtdnrc/gages/43B05950
# https://geoconnex.us/mtdnrc/gages/43B05990
# https://geoconnex.us/mtdnrc/gages/43B09200
# https://geoconnex.us/mtdnrc/gages/43B09510
# https://geoconnex.us/mtdnrc/gages/43B09550
# https://geoconnex.us/mtdnrc/gages/43B09710
# https://geoconnex.us/mtdnrc/gages/43B09800
# https://geoconnex.us/mtdnrc/gages/43B10000
# https://geoconnex.us/mtdnrc/gages/43B89500
# https://geoconnex.us/mtdnrc/gages/43B91550
# https://geoconnex.us/mtdnrc/gages/43B91620
# https://geoconnex.us/mtdnrc/gages/43B91750
# https://geoconnex.us/mtdnrc/gages/43B91820
# https://geoconnex.us/mtdnrc/gages/43B95700
# https://geoconnex.us/mtdnrc/gages/43BJ03800
# https://geoconnex.us/mtdnrc/gages/43BJ05200
# https://geoconnex.us/mtdnrc/gages/43BJ05800
# https://geoconnex.us/mtdnrc/gages/43BJ07200
# https://geoconnex.us/mtdnrc/gages/43BJ07800
# https://geoconnex.us/mtdnrc/gages/43BJ09000
# https://geoconnex.us/mtdnrc/gages/43BV02000
# https://geoconnex.us/mtdnrc/gages/43BV04000
# https://geoconnex.us/mtdnrc/gages/43BV05000
# https://geoconnex.us/mtdnrc/gages/43BV07000
# https://geoconnex.us/mtdnrc/gages/43BV08000
# https://geoconnex.us/mtdnrc/gages/43BV09000
# https://geoconnex.us/mtdnrc/gages/43D01900
# https://geoconnex.us/mtdnrc/gages/43Q05900
# https://geoconnex.us/mtdnrc/gages/43Q06300
# https://geoconnex.us/mtdnrc/gages/43Q06400
# https://geoconnex.us/mtdnrc/gages/46J07500
# https://geoconnex.us/mtdnrc/gages/46J07800
# https://geoconnex.us/mtdnrc/gages/76E1500
# https://geoconnex.us/mtdnrc/gages/76E2000
# https://geoconnex.us/mtdnrc/gages/76E2100
# https://geoconnex.us/mtdnrc/gages/76E2200
# https://geoconnex.us/mtdnrc/gages/76E3000
# https://geoconnex.us/mtdnrc/gages/76E4000
# https://geoconnex.us/mtdnrc/gages/76F02000
# https://geoconnex.us/mtdnrc/gages/76F02900
# https://geoconnex.us/mtdnrc/gages/76F03500
# https://geoconnex.us/mtdnrc/gages/76F05000
# https://geoconnex.us/mtdnrc/gages/76F05200
# https://geoconnex.us/mtdnrc/gages/76F05300
# https://geoconnex.us/mtdnrc/gages/76F2000
# https://geoconnex.us/mtdnrc/gages/76F2100
# https://geoconnex.us/mtdnrc/gages/76F2200
# https://geoconnex.us/mtdnrc/gages/76F37400
# https://geoconnex.us/mtdnrc/gages/76G05990
# https://geoconnex.us/mtdnrc/gages/76G24605
# https://geoconnex.us/mtdnrc/gages/76GJ07100
# https://geoconnex.us/mtdnrc/gages/76GJ2089
# https://geoconnex.us/mtdnrc/gages/76GJ8000
# https://geoconnex.us/mtdnrc/gages/76GJ8080
# https://geoconnex.us/mtdnrc/gages/76H1200
# https://geoconnex.us/mtdnrc/gages/76H1500
# https://geoconnex.us/mtdnrc/gages/76HB01000
# https://geoconnex.us/mtdnrc/gages/76HB01500
# https://geoconnex.us/mtdnrc/gages/76HB02800
# https://geoconnex.us/mtdnrc/gages/76HB03000
# https://geoconnex.us/mtdnrc/gages/76HB05500
# https://geoconnex.us/mtdnrc/gages/76HB05800
# https://geoconnex.us/mtdnrc/gages/76HB09500
# https://geoconnex.us/mtdnrc/gages/76HB09550
# https://geoconnex.us/mtdnrc/gages/76HB09600
# https://geoconnex.us/mtdnrc/gages/76HF05000
# https://geoconnex.us/mtdnrc/gages/76HF3503
# https://geoconnex.us/mtdnrc/gages/76HF3513
# https://geoconnex.us/mtdnrc/gages/76LJ001
# https://geoconnex.us/mtdnrc/gages/76LJ002
# https://geoconnex.us/mtdnrc/gages/76LJ003
# https://geoconnex.us/mtdnrc/gages/76LJ004
# https://geoconnex.us/mtdnrc/gages/76LJ005
# https://geoconnex.us/mtdnrc/gages/76LJ07500
# https://geoconnex.us/mtdnrc/gages/76LJ09900
# https://geoconnex.us/mtdnrc/gages/76M01100
# https://geoconnex.us/mtdnrc/gages/SR001
# https://geoconnex.us/mtdnrc/gages/SR002
# https://geoconnex.us/mtdnrc/gages/SR004
# https://geoconnex.us/mtdnrc/gages/SR006
# https://geoconnex.us/mtdnrc/gages/SR007
# Complete
