# %% [markdown]
# ## Translate Nebraska  stream gage data into Geoconnex

# %% [markdown]
# Points brought in via R script which will be included in this github repo.
# Source is: https://nednr.nebraska.gov/IwipApi/api/v1/StreamGage/GetStationLis

# %%
import arcpy

# Set the workspace environment
arcpy.env.workspace = r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb"

# Define the input layer
NE_gage = "NE_gages"

# Export to modify
arcpy.conversion.ExportFeatures(
    in_features="NE_gages",
    out_features=r"C:\Users\ewiggans\Desktop\GeoconnexNPDES\GeoconnexNPDES\GeoconnexNPDES.gdb\NE_gages_final",
    where_clause="",
    use_field_alias_as_name="NOT_USE_ALIAS",
    field_mapping='StatnNm "StatnNm" true true false 80 Text 0 0,First,#,NE_gages,StatnNm,0,80;SourcNm "SourcNm" true true false 80 Text 0 0,First,#,NE_gages,SourcNm,0,80;SttnNmb "SttnNmb" true true false 80 Text 0 0,First,#,NE_gages,SttnNmb,0,80;RivrBsn "RivrBsn" true true false 80 Text 0 0,First,#,NE_gages,RivrBsn,0,80;FldOffc "FldOffc" true true false 80 Text 0 0,First,#,NE_gages,FldOffc,0,80;SttnTyD "SttnTyD" true true false 80 Text 0 0,First,#,NE_gages,SttnTyD,0,80;Dwnstrm "Dwnstrm" true true false 4 Long 0 0,First,#,NE_gages,Dwnstrm,-1,-1;TimeZon "TimeZon" true true false 80 Text 0 0,First,#,NE_gages,TimeZon,0,80;Elevatn "Elevatn" true true false 8 Double 0 0,First,#,NE_gages,Elevatn,-1,-1;ElvtnUn "ElvtnUn" true true false 80 Text 0 0,First,#,NE_gages,ElvtnUn,0,80;IsActiv "IsActiv" true true false 4 Long 0 0,First,#,NE_gages,IsActiv,-1,-1;uri "uri" true true false 254 Text 0 0,First,#,NE_gages,uri,0,254;name "name" true true false 254 Text 0 0,First,#,NE_gages,name,0,254;id "id" true true false 254 Text 0 0,First,#,NE_gages,id,0,254',
    sort_field=None
)

# reassign variable name
NE_gage = "NE_gages_final"

# Define a list of field names and their types
field_list = [
    ("uri", "TEXT"),
    ("name", "TEXT"),
    ("id", "TEXT"),
    ("provider_name", "TEXT"),
    ("provider_id", "TEXT"),
    ("provider_url", "TEXT"),
    ("provider_code", "TEXT"),
    ("mainstem_uri", "TEXT"),
    ("comid", "TEXT")
]

# Add the new fields using a loop
for field_name, field_type in field_list:
    arcpy.AddField_management(NE_gage, field_name, field_type)

# Confirm the field addition
field_names = [field.name for field in arcpy.ListFields(NE_gage)]
print("Fields in the layer after addition:", field_names)
# Out:
# Fields in the layer after addition: ['OBJECTID', 'Shape', 'StatnNm', 'SourcNm', 'SttnNmb', 'RivrBsn', 'FldOffc', 'SttnTyD', 'Dwnstrm', 'TimeZon', 'Elevatn', 'ElvtnUn', 'IsActiv', 'uri', 'name', 'id', 'provider_name', 'provider_id', 'provider_url', 'provider_code', 'mainstem_uri', 'comid']

# %%
# Confirm unique ID in identifier field
# Field to check for uniqueness
field_name = "SttnNmb"

# Use a set to keep track of unique values encountered in the field
unique_values = set()

# Initialize a counter to keep track of the total number of rows
total_rows = 0

# Initialize a flag to check for spaces
has_spaces = False

# Start a search cursor to iterate through the rows and check for unique values and spaces
with arcpy.da.UpdateCursor(NE_gage, field_name) as cursor:
    for row in cursor:
        total_rows += 1
        value = row[0]
        if value in unique_values:
            print(f"Non-unique value found: {value}")
        else:
            unique_values.add(value)

        if " " in value:
            has_spaces = True
            # Replace spaces with "-"
            row[0] = value.replace(" ", "-")
            cursor.updateRow(row)

# Check if the number of unique values is the same as the total number of rows
if len(unique_values) == total_rows:
    print("All values in the 'Identifier' field are unique.")
else:
    print("There are duplicate values in the 'Identifier' field.")

# Check if there are any spaces in the 'Identifier' field
if has_spaces:
    print("There were spaces in the 'Identifier' field. They have been replaced with '-'.")
else:
    print("No spaces found in the 'Identifier' field.")
# Out:
# All values in the 'Identifier' field are unique.
# No spaces found in the 'Identifier' field.

# %%
#set Identifier field to id and name
#fields to update
id_field = "id"
name_field = "name"
field_name = "SttnNmb"

# Calculate the 'id' field and 'name' field using the 'Identifier' field
expression = "!" + field_name + "!"
codeblock = ""

# Use the CalculateField tool to perform the field calculation
arcpy.CalculateField_management(NE_gage, id_field, expression, "PYTHON3", codeblock)
arcpy.CalculateField_management(NE_gage, name_field, expression, "PYTHON3", codeblock)

#print("Updated 'id' and 'name' fields with values from the 'Identifier' field.")

arcpy.CalculateField_management(NE_gage, "provider_name", "'Nebraska Department of Natural Resources'")
arcpy.CalculateField_management(NE_gage, "provider_url", "'https://nednr.aquaticinformatics.net/Data'")
arcpy.CalculateField_management(NE_gage, "provider_id", "!" + field_name +"!")
arcpy.CalculateField_management(NE_gage, "provider_code", "'nednr'")
# Out:
# <Result 'NE_gages_final'>

# %%
#thank you Ben, four for you Ben
codeblock = """
def url_join(*parts: list) -> str:
    return '/'.join([str(p).strip().strip('/') for p in parts])
"""
##geoconnex.us/iow/wyseo/gages/id

expression = """url_join("https://geoconnex.us/nednr/gages", !id!)"""
arcpy.management.CalculateField(NE_gage, "uri", expression, "PYTHON3", codeblock)
print("uri calculated")
# Out:
# uri calculated

# %%
##Read in the download table

# %%
import pandas as pd
pd.set_option('display.width', 1000)

# Path to the CSV file
csv_file_path = r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\List-20231011193703.csv"


# Read the CSV file into a pandas DataFrame


df = pd.read_csv(csv_file_path, skiprows=[0])


# Display the first few rows of the data frame to verify the data
print(df.head())
df.columns = df.columns.str.replace(' ', '_')
print(df.columns)
# Out:
#                   Data Set Id  ...        Status
# 0  Discharge.Working@00002000  ...  Flow Present
# 1  Discharge.Working@00007000  ...  Flow Present
# 2  Discharge.Working@00009000  ...  Flow Present
# 3  Discharge.Working@00016000  ...  Flow Present
# 4  Discharge.Working@00017200  ...  Flow Present
#
# [5 rows x 7 columns]
# Index(['Data_Set_Id', 'Location', 'Location_Folder', 'Start_of_Record', 'End_of_Record', 'Value', 'Status'], dtype='object')

# %%
# Perform the field calculations on the pandas DataFrame
df["location_id"] = df['Data_Set_Id'].str.replace(r".*@", "", regex=True)
# About uri, not about url 
df["about_uri"] = "https://geoconnex.us/nednr/gages/" + df["location_id"]
df["data_set_type"] = df["Data_Set_Id"].str.replace(r"@.*", "", regex=True)
df["data_set_path"] = df["data_set_type"].str.replace(".", "/", 1)

#update to format of Nebraska gages
df["url"] = "https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/" + df["location_id"] + "/DataSet/Discharge/Working/Interval/Latest"
df["provider_code"] = "nednr"
df["parameter_name"] = df["data_set_type"]
df["parameter_group"] = "discharge"
df["parameter_id"] = df["provider_code"] + "-" + df["parameter_group"]
df["name"] = df["Data_Set_Id"]

print("Data Frame updated")
# Out:
# Data Frame updated

# %%
df.head()
# Out:
#                   Data_Set_Id  ...                        name
# 0  Discharge.Working@00002000  ...  Discharge.Working@00002000
# 1  Discharge.Working@00007000  ...  Discharge.Working@00007000
# 2  Discharge.Working@00009000  ...  Discharge.Working@00009000
# 3  Discharge.Working@00016000  ...  Discharge.Working@00016000
# 4  Discharge.Working@00017200  ...  Discharge.Working@00017200
#
# [5 rows x 17 columns]

# %%
# Print the first five rows of the "data_set_url" column
pd.options.display.max_colwidth = 300
print(df["url"].head())
# Out:
# 0    https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00002000/DataSet/Discharge/Working/Interval/Latest
# 1    https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00007000/DataSet/Discharge/Working/Interval/Latest
# 2    https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00009000/DataSet/Discharge/Working/Interval/Latest
# 3    https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00016000/DataSet/Discharge/Working/Interval/Latest
# 4    https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00017200/DataSet/Discharge/Working/Interval/Latest
# Name: url, dtype: object

# %%
#Perform final field calculations on pandas DataFrame

end_df = df[["about_uri", "url", "name", "provider_code", "parameter_id", "parameter_name", "parameter_group"]]
end_df.head()
end_df.to_csv("C:\\Users\\ewiggans\\Desktop\\GeoConnexMap\\NebraskaGage\\NE_download_table.csv")
#Export and write to new CSV

# %%
import json
import requests
from shapely.geometry import shape, Point

def get_comid_intersect(geom):
    # Convert the input geom to GeoJSON using Shapely
    point = Point(geom)

    # Convert the Point to GeoJSON
    geom_geojson = shape(point).__geo_interface__

    url = 'https://nhdpv2-census.internetofwater.app/collections/2020/items?filter-lang=cql-json'
    filter_ = {
        'intersects': [
            {'property': 'shape'},
            geom_geojson  # Use the Shapely-converted GeoJSON
        ]
    }
    headers = {
        'Content-Type': 'application/query-cql-json'
    }
    r = requests.post(url, headers=headers, json=filter_)
    fc = r.json()
    if 'features' in fc and len(fc['features']) > 0:
        feature = fc['features'][0]
        return feature['properties']['featureid']
    else:
        return None

# Update Cursor
with arcpy.da.UpdateCursor(NE_gage, ["Shape", "comid"]) as cursor:
    for row in cursor:
        geom = row[0]
        comid = get_comid_intersect(geom)
        if comid is not None:
            print(comid, end='\r', flush=True)
            row[1] = comid
            cursor.updateRow(row)


print("comid calculated")
# Out:
# comid calculated

# %%
# Read in the CSV file as a geodatabase table
csv_table = r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\nhdpv2_lookup.csv"
csv_table_name = "NHDPV2_Lookup"
arcpy.TableToTable_conversion(csv_table, arcpy.env.workspace, csv_table_name)

# Add a new field 'comid_text' to the CSV table with a data type of TEXT
arcpy.AddField_management(csv_table_name, "comid_text", "TEXT")

# Calculate the 'comid_text' field by copying the values from the 'comid' field
expression = "!comid!"
codeblock = ""
arcpy.CalculateField_management(csv_table_name, "comid_text", expression, "PYTHON3", codeblock)

print("Added 'comid_text' field and set its values equal to 'comid' as text.")
# Out:
# Added 'comid_text' field and set its values equal to 'comid' as text.

# %%
# Join the CSV table to the "WyomingStreamGage" feature class based on the "comid" field
arcpy.AddJoin_management(NE_gage, "comid", csv_table_name, "comid_text", "KEEP_COMMON")

# Calculate the "mainstem_uri" field to be equal to the "uri" field in the CSV table
expression = "!{}.uri!".format(csv_table_name)
arcpy.CalculateField_management(NE_gage, "mainstem_uri", expression, "PYTHON3")

# Remove the join to the CSV table
arcpy.RemoveJoin_management(NE_gage, csv_table_name)
# Out:
# <Result 'NE_gages_final'>

# %%
# Define the output GeoJSON file path
output_geojson_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\NE_gage_export.geojson"

#set projection to wgs84
arcpy.management.DefineProjection(
    in_dataset="NE_gages_final",
    coor_system='GEOGCS["GCS_WGS_1984",DATUM["D_WGS_1984",SPHEROID["WGS_1984",6378137.0,298.257223563]],PRIMEM["Greenwich",0.0],UNIT["Degree",0.0174532925199433]]'
)


# Export the feature class to GeoJSON
arcpy.FeaturesToJSON_conversion(in_features = NE_gage, 
                                out_json_file = output_geojson_file,
                                geoJSON = "GEOJSON")


print(f"Exported {NE_gage} to {output_geojson_file} in GeoJSON format.")
# Out:
# Exported NE_gages_final to C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\NE_gage_export.geojson in GeoJSON format.

# %%
import geopandas as gpd

def group_data(gdf, gpkg_file, csv_file):
    # Make mapping dictionary
    mapping = {}
    df = pd.read_csv(csv_file)
    for index, row in df.iterrows():
        location = row['about_uri']
        #print(location)
        data = row.drop(['about_uri'])
        if location not in mapping:
            mapping[location] = []
        mapping[location].append(data.to_dict())
    #print(mapping)
    # Apply mapping
    for index, row in gdf.iterrows():
        location = row['uri']
        if location in mapping:
            gdf.at[index, 'data'] = \
                json.dumps(mapping[location])
        #print(location)
    gdf.to_file(gpkg_file, driver="GPKG")

gdf = gpd.read_file(r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\NE_gage_export.geojson")
csv_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\NE_download_table.csv"
gpkg_file = r"C:\Users\ewiggans\Desktop\GeoConnexMap\NebraskaGage\NE_gages.gpkg"
group_data(gdf, gpkg_file, csv_file)
print("Complete")
# Out:
# https://geoconnex.us/nednr/gages/00002000
# https://geoconnex.us/nednr/gages/00007000
# https://geoconnex.us/nednr/gages/00009000
# https://geoconnex.us/nednr/gages/00016000
# https://geoconnex.us/nednr/gages/00017200
# https://geoconnex.us/nednr/gages/00019000
# https://geoconnex.us/nednr/gages/00019500
# https://geoconnex.us/nednr/gages/00024000
# https://geoconnex.us/nednr/gages/00027000
# https://geoconnex.us/nednr/gages/00039000
# https://geoconnex.us/nednr/gages/00053000
# https://geoconnex.us/nednr/gages/00057000
# https://geoconnex.us/nednr/gages/00061500
# https://geoconnex.us/nednr/gages/00062000
# https://geoconnex.us/nednr/gages/00062500
# https://geoconnex.us/nednr/gages/00067000
# https://geoconnex.us/nednr/gages/00073000
# https://geoconnex.us/nednr/gages/00075000
# https://geoconnex.us/nednr/gages/00079000
# https://geoconnex.us/nednr/gages/00082000
# https://geoconnex.us/nednr/gages/00082100
# https://geoconnex.us/nednr/gages/00099000
# https://geoconnex.us/nednr/gages/00106000
# https://geoconnex.us/nednr/gages/00106100
# https://geoconnex.us/nednr/gages/00114000
# https://geoconnex.us/nednr/gages/00133000
# https://geoconnex.us/nednr/gages/00136000
# https://geoconnex.us/nednr/gages/00142001
# https://geoconnex.us/nednr/gages/00144200
# https://geoconnex.us/nednr/gages/00145100
# https://geoconnex.us/nednr/gages/00145700
# https://geoconnex.us/nednr/gages/00147000
# https://geoconnex.us/nednr/gages/00147001
# https://geoconnex.us/nednr/gages/00219500
# https://geoconnex.us/nednr/gages/00224600
# https://geoconnex.us/nednr/gages/00225000
# https://geoconnex.us/nednr/gages/00228500
# https://geoconnex.us/nednr/gages/00229300
# https://geoconnex.us/nednr/gages/00231700
# https://geoconnex.us/nednr/gages/00232500
# https://geoconnex.us/nednr/gages/06444000
# https://geoconnex.us/nednr/gages/06453600
# https://geoconnex.us/nednr/gages/06454000
# https://geoconnex.us/nednr/gages/06454050
# https://geoconnex.us/nednr/gages/06454100
# https://geoconnex.us/nednr/gages/06454500
# https://geoconnex.us/nednr/gages/06455500
# https://geoconnex.us/nednr/gages/06456500
# https://geoconnex.us/nednr/gages/06457500
# https://geoconnex.us/nednr/gages/06459025
# https://geoconnex.us/nednr/gages/06459175
# https://geoconnex.us/nednr/gages/06459500
# https://geoconnex.us/nednr/gages/06461500
# https://geoconnex.us/nednr/gages/06463500
# https://geoconnex.us/nednr/gages/06464900
# https://geoconnex.us/nednr/gages/06464930
# https://geoconnex.us/nednr/gages/06465700
# https://geoconnex.us/nednr/gages/06601000
# https://geoconnex.us/nednr/gages/06610720
# https://geoconnex.us/nednr/gages/06610732
# https://geoconnex.us/nednr/gages/06610770
# https://geoconnex.us/nednr/gages/06610793
# https://geoconnex.us/nednr/gages/06610795
# https://geoconnex.us/nednr/gages/06674500
# https://geoconnex.us/nednr/gages/06677500
# https://geoconnex.us/nednr/gages/06678000
# https://geoconnex.us/nednr/gages/06678500
# https://geoconnex.us/nednr/gages/06679000
# https://geoconnex.us/nednr/gages/06679500
# https://geoconnex.us/nednr/gages/06680000
# https://geoconnex.us/nednr/gages/06680970
# https://geoconnex.us/nednr/gages/06681000
# https://geoconnex.us/nednr/gages/06681998
# https://geoconnex.us/nednr/gages/06681999
# https://geoconnex.us/nednr/gages/06682000
# https://geoconnex.us/nednr/gages/06682000
# https://geoconnex.us/nednr/gages/06682000
# https://geoconnex.us/nednr/gages/06682500
# https://geoconnex.us/nednr/gages/06683000
# https://geoconnex.us/nednr/gages/06684000
# https://geoconnex.us/nednr/gages/06684498
# https://geoconnex.us/nednr/gages/06684499
# https://geoconnex.us/nednr/gages/06684500
# https://geoconnex.us/nednr/gages/06684500
# https://geoconnex.us/nednr/gages/06684500
# https://geoconnex.us/nednr/gages/06685000
# https://geoconnex.us/nednr/gages/06686000
# https://geoconnex.us/nednr/gages/06687000
# https://geoconnex.us/nednr/gages/06687500
# https://geoconnex.us/nednr/gages/06691000
# https://geoconnex.us/nednr/gages/06692000
# https://geoconnex.us/nednr/gages/06692500
# https://geoconnex.us/nednr/gages/06693000
# https://geoconnex.us/nednr/gages/06764880
# https://geoconnex.us/nednr/gages/06764900
# https://geoconnex.us/nednr/gages/06765500
# https://geoconnex.us/nednr/gages/06765980
# https://geoconnex.us/nednr/gages/06765990
# https://geoconnex.us/nednr/gages/06766000
# https://geoconnex.us/nednr/gages/06766000
# https://geoconnex.us/nednr/gages/06766000
# https://geoconnex.us/nednr/gages/06766498
# https://geoconnex.us/nednr/gages/06766499
# https://geoconnex.us/nednr/gages/06766500
# https://geoconnex.us/nednr/gages/06766500
# https://geoconnex.us/nednr/gages/06766500
# https://geoconnex.us/nednr/gages/06766650
# https://geoconnex.us/nednr/gages/06767500
# https://geoconnex.us/nednr/gages/06768000
# https://geoconnex.us/nednr/gages/06768000
# https://geoconnex.us/nednr/gages/06770000
# https://geoconnex.us/nednr/gages/06770200
# https://geoconnex.us/nednr/gages/06770500
# https://geoconnex.us/nednr/gages/06780000
# https://geoconnex.us/nednr/gages/06783500
# https://geoconnex.us/nednr/gages/06784800
# https://geoconnex.us/nednr/gages/06785000
# https://geoconnex.us/nednr/gages/06787000
# https://geoconnex.us/nednr/gages/06787500
# https://geoconnex.us/nednr/gages/06788500
# https://geoconnex.us/nednr/gages/06788988
# https://geoconnex.us/nednr/gages/06791500
# https://geoconnex.us/nednr/gages/06792000
# https://geoconnex.us/nednr/gages/06792500
# https://geoconnex.us/nednr/gages/06793000
# https://geoconnex.us/nednr/gages/06793500
# https://geoconnex.us/nednr/gages/06794500
# https://geoconnex.us/nednr/gages/06796000
# https://geoconnex.us/nednr/gages/06796500
# https://geoconnex.us/nednr/gages/06796973
# https://geoconnex.us/nednr/gages/06798000
# https://geoconnex.us/nednr/gages/06798500
# https://geoconnex.us/nednr/gages/06798780
# https://geoconnex.us/nednr/gages/06799000
# https://geoconnex.us/nednr/gages/06799080
# https://geoconnex.us/nednr/gages/06799230
# https://geoconnex.us/nednr/gages/06799315
# https://geoconnex.us/nednr/gages/06799350
# https://geoconnex.us/nednr/gages/06799385
# https://geoconnex.us/nednr/gages/06799445
# https://geoconnex.us/nednr/gages/06799450
# https://geoconnex.us/nednr/gages/06799500
# https://geoconnex.us/nednr/gages/06799510
# https://geoconnex.us/nednr/gages/06800500
# https://geoconnex.us/nednr/gages/06801000
# https://geoconnex.us/nednr/gages/06803080
# https://geoconnex.us/nednr/gages/06803486
# https://geoconnex.us/nednr/gages/06803500
# https://geoconnex.us/nednr/gages/06803513
# https://geoconnex.us/nednr/gages/06805500
# https://geoconnex.us/nednr/gages/06806500
# https://geoconnex.us/nednr/gages/06831500
# https://geoconnex.us/nednr/gages/06834000
# https://geoconnex.us/nednr/gages/06835000
# https://geoconnex.us/nednr/gages/06837000
# https://geoconnex.us/nednr/gages/06837300
# https://geoconnex.us/nednr/gages/06838500
# https://geoconnex.us/nednr/gages/06839970
# https://geoconnex.us/nednr/gages/06840000
# https://geoconnex.us/nednr/gages/06841000
# https://geoconnex.us/nednr/gages/06843400
# https://geoconnex.us/nednr/gages/06843500
# https://geoconnex.us/nednr/gages/06844000
# https://geoconnex.us/nednr/gages/06844210
# https://geoconnex.us/nednr/gages/06850000
# https://geoconnex.us/nednr/gages/06851000
# https://geoconnex.us/nednr/gages/06851090
# https://geoconnex.us/nednr/gages/06851500
# https://geoconnex.us/nednr/gages/06852000
# https://geoconnex.us/nednr/gages/06852500
# https://geoconnex.us/nednr/gages/06880000
# https://geoconnex.us/nednr/gages/06880500
# https://geoconnex.us/nednr/gages/06880800
# https://geoconnex.us/nednr/gages/06881000
# https://geoconnex.us/nednr/gages/06881380
# https://geoconnex.us/nednr/gages/06881500
# https://geoconnex.us/nednr/gages/06882000
# https://geoconnex.us/nednr/gages/06883555
# https://geoconnex.us/nednr/gages/06883940
# https://geoconnex.us/nednr/gages/06884000
# https://geoconnex.us/nednr/gages/06884005
# https://geoconnex.us/nednr/gages/11x
# https://geoconnex.us/nednr/gages/13x
# https://geoconnex.us/nednr/gages/16x
# https://geoconnex.us/nednr/gages/LVABKS
# https://geoconnex.us/nednr/gages/00001000
# https://geoconnex.us/nednr/gages/00002692
# https://geoconnex.us/nednr/gages/00002696
# https://geoconnex.us/nednr/gages/00003000
# https://geoconnex.us/nednr/gages/00006000
# https://geoconnex.us/nednr/gages/00010000
# https://geoconnex.us/nednr/gages/00013000
# https://geoconnex.us/nednr/gages/00021000
# https://geoconnex.us/nednr/gages/00022000
# https://geoconnex.us/nednr/gages/00029000
# https://geoconnex.us/nednr/gages/00033000
# https://geoconnex.us/nednr/gages/00037000
# https://geoconnex.us/nednr/gages/00038100
# https://geoconnex.us/nednr/gages/00038200
# https://geoconnex.us/nednr/gages/00040000
# https://geoconnex.us/nednr/gages/00046000
# https://geoconnex.us/nednr/gages/00054700
# https://geoconnex.us/nednr/gages/00056000
# https://geoconnex.us/nednr/gages/00063000
# https://geoconnex.us/nednr/gages/00069000
# https://geoconnex.us/nednr/gages/00072000
# https://geoconnex.us/nednr/gages/00076000
# https://geoconnex.us/nednr/gages/00076500
# https://geoconnex.us/nednr/gages/00078000
# https://geoconnex.us/nednr/gages/00084000
# https://geoconnex.us/nednr/gages/00086000
# https://geoconnex.us/nednr/gages/00088000
# https://geoconnex.us/nednr/gages/00088500
# https://geoconnex.us/nednr/gages/00089000
# https://geoconnex.us/nednr/gages/00090000
# https://geoconnex.us/nednr/gages/00091000
# https://geoconnex.us/nednr/gages/00092000
# https://geoconnex.us/nednr/gages/00093000
# https://geoconnex.us/nednr/gages/00098000
# https://geoconnex.us/nednr/gages/00100500
# https://geoconnex.us/nednr/gages/00104000
# https://geoconnex.us/nednr/gages/00105500
# https://geoconnex.us/nednr/gages/00115100
# https://geoconnex.us/nednr/gages/00117000
# https://geoconnex.us/nednr/gages/00120000
# https://geoconnex.us/nednr/gages/00121000
# https://geoconnex.us/nednr/gages/00123000
# https://geoconnex.us/nednr/gages/00126000
# https://geoconnex.us/nednr/gages/00130000
# https://geoconnex.us/nednr/gages/00138000
# https://geoconnex.us/nednr/gages/00140003
# https://geoconnex.us/nednr/gages/00141000
# https://geoconnex.us/nednr/gages/00144400
# https://geoconnex.us/nednr/gages/00146000
# https://geoconnex.us/nednr/gages/00148000
# https://geoconnex.us/nednr/gages/00149000
# https://geoconnex.us/nednr/gages/06690500
# https://geoconnex.us/nednr/gages/06763500
# https://geoconnex.us/nednr/gages/06770195
# https://geoconnex.us/nednr/gages/06770240
# https://geoconnex.us/nednr/gages/06772000
# https://geoconnex.us/nednr/gages/06772100
# https://geoconnex.us/nednr/gages/06842500
# https://geoconnex.us/nednr/gages/06847000
# https://geoconnex.us/nednr/gages/06879900
# https://geoconnex.us/nednr/gages/06881200
# https://geoconnex.us/nednr/gages/FCWICNE
# https://geoconnex.us/nednr/gages/GDSNE
# {'https://geoconnex.us/nednr/gages/00002000': [{'Unnamed: 0': 0, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00002000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00002000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00007000': [{'Unnamed: 0': 1, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00007000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00007000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00009000': [{'Unnamed: 0': 2, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00009000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00009000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00016000': [{'Unnamed: 0': 3, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00016000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00016000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00017200': [{'Unnamed: 0': 4, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00017200/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00017200', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00019000': [{'Unnamed: 0': 5, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00019000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00019000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00019500': [{'Unnamed: 0': 6, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00019500/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00019500', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00024000': [{'Unnamed: 0': 7, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00024000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00024000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00027000': [{'Unnamed: 0': 8, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00027000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00027000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00039000': [{'Unnamed: 0': 9, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00039000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00039000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharge'}], 'https://geoconnex.us/nednr/gages/00053000': [{'Unnamed: 0': 10, 'url': 'https://nednr.aquaticinformatics.net/Data/DataSet/Summary/Location/00053000/DataSet/Discharge/Working/Interval/Latest', 'name': 'Discharge.Working@00053000', 'provider_code': 'nednr', 'parameter_id': 'nednr-discharge', 'parameter_name': 'Discharge.Working', 'parameter_group': 'discharg ...
# https://geoconnex.us/nednr/gages/00062500
# https://geoconnex.us/nednr/gages/06444000
# https://geoconnex.us/nednr/gages/00410000
# https://geoconnex.us/nednr/gages/06454000
# https://geoconnex.us/nednr/gages/00072000
# https://geoconnex.us/nednr/gages/00079000
# https://geoconnex.us/nednr/gages/06454050
# https://geoconnex.us/nednr/gages/00038100
# https://geoconnex.us/nednr/gages/00038200
# https://geoconnex.us/nednr/gages/00084000
# https://geoconnex.us/nednr/gages/00029000
# https://geoconnex.us/nednr/gages/00062000
# https://geoconnex.us/nednr/gages/06454100
# https://geoconnex.us/nednr/gages/00078000
# https://geoconnex.us/nednr/gages/00089000
# https://geoconnex.us/nednr/gages/00013000
# https://geoconnex.us/nednr/gages/00104000
# https://geoconnex.us/nednr/gages/00063000
# https://geoconnex.us/nednr/gages/00086000
# https://geoconnex.us/nednr/gages/00046000
# https://geoconnex.us/nednr/gages/00069000
# https://geoconnex.us/nednr/gages/00123000
# https://geoconnex.us/nednr/gages/06454500
# https://geoconnex.us/nednr/gages/06455500
# https://geoconnex.us/nednr/gages/00081000
# https://geoconnex.us/nednr/gages/00100000
# https://geoconnex.us/nednr/gages/06456500
# https://geoconnex.us/nednr/gages/06457500
# https://geoconnex.us/nednr/gages/06459025
# https://geoconnex.us/nednr/gages/06459175
# https://geoconnex.us/nednr/gages/00001000
# https://geoconnex.us/nednr/gages/06459500
# https://geoconnex.us/nednr/gages/06464900
# https://geoconnex.us/nednr/gages/06464930
# https://geoconnex.us/nednr/gages/06465700
# https://geoconnex.us/nednr/gages/00101100
# https://geoconnex.us/nednr/gages/00056000
# https://geoconnex.us/nednr/gages/00002692
# https://geoconnex.us/nednr/gages/00145100
# https://geoconnex.us/nednr/gages/00115100
# https://geoconnex.us/nednr/gages/00002696
# https://geoconnex.us/nednr/gages/00225000
# https://geoconnex.us/nednr/gages/06677500
# https://geoconnex.us/nednr/gages/06678000
# https://geoconnex.us/nednr/gages/06678500
# https://geoconnex.us/nednr/gages/00040000
# https://geoconnex.us/nednr/gages/06679000
# https://geoconnex.us/nednr/gages/06679500
# https://geoconnex.us/nednr/gages/06680000
# https://geoconnex.us/nednr/gages/00148000
# https://geoconnex.us/nednr/gages/00149000
# https://geoconnex.us/nednr/gages/00022000
# https://geoconnex.us/nednr/gages/06681000
# https://geoconnex.us/nednr/gages/00099000
# https://geoconnex.us/nednr/gages/06680970
# https://geoconnex.us/nednr/gages/00021000
# https://geoconnex.us/nednr/gages/00144400
# https://geoconnex.us/nednr/gages/06682000
# https://geoconnex.us/nednr/gages/06681999
# https://geoconnex.us/nednr/gages/06681998
# https://geoconnex.us/nednr/gages/00106000
# https://geoconnex.us/nednr/gages/00106100
# https://geoconnex.us/nednr/gages/06682500
# https://geoconnex.us/nednr/gages/00133000
# https://geoconnex.us/nednr/gages/00024000
# https://geoconnex.us/nednr/gages/00002000
# https://geoconnex.us/nednr/gages/00003000
# https://geoconnex.us/nednr/gages/06683000
# https://geoconnex.us/nednr/gages/06684000
# https://geoconnex.us/nednr/gages/00009000
# https://geoconnex.us/nednr/gages/06684500
# https://geoconnex.us/nednr/gages/06684498
# https://geoconnex.us/nednr/gages/06684499
# https://geoconnex.us/nednr/gages/06685000
# https://geoconnex.us/nednr/gages/00010000
# https://geoconnex.us/nednr/gages/00039000
# https://geoconnex.us/nednr/gages/00019000
# https://geoconnex.us/nednr/gages/00030000
# https://geoconnex.us/nednr/gages/00080000
# https://geoconnex.us/nednr/gages/00144200
# https://geoconnex.us/nednr/gages/00105500
# https://geoconnex.us/nednr/gages/00088000
# https://geoconnex.us/nednr/gages/00007000
# https://geoconnex.us/nednr/gages/00082000
# https://geoconnex.us/nednr/gages/06686000
# https://geoconnex.us/nednr/gages/00098000
# https://geoconnex.us/nednr/gages/00120000
# https://geoconnex.us/nednr/gages/00017200
# https://geoconnex.us/nednr/gages/00067000
# https://geoconnex.us/nednr/gages/00146000
# https://geoconnex.us/nednr/gages/06687000
# https://geoconnex.us/nednr/gages/06687500
# https://geoconnex.us/nednr/gages/00138000
# https://geoconnex.us/nednr/gages/06690500
# https://geoconnex.us/nednr/gages/00076000
# https://geoconnex.us/nednr/gages/00114000
# https://geoconnex.us/nednr/gages/00121000
# https://geoconnex.us/nednr/gages/06691000
# https://geoconnex.us/nednr/gages/00016000
# https://geoconnex.us/nednr/gages/00136000
# https://geoconnex.us/nednr/gages/06692000
# https://geoconnex.us/nednr/gages/00027000
# https://geoconnex.us/nednr/gages/06692500
# https://geoconnex.us/nednr/gages/06693000
# https://geoconnex.us/nednr/gages/00219500
# https://geoconnex.us/nednr/gages/06763500
# https://geoconnex.us/nednr/gages/00147000
# https://geoconnex.us/nednr/gages/00147001
# https://geoconnex.us/nednr/gages/06764900
# https://geoconnex.us/nednr/gages/06765500
# https://geoconnex.us/nednr/gages/00140000
# https://geoconnex.us/nednr/gages/00140003
# https://geoconnex.us/nednr/gages/00142001
# https://geoconnex.us/nednr/gages/00144000
# https://geoconnex.us/nednr/gages/00228500
# https://geoconnex.us/nednr/gages/06765980
# https://geoconnex.us/nednr/gages/06765990
# https://geoconnex.us/nednr/gages/06766000
# https://geoconnex.us/nednr/gages/00143000
# https://geoconnex.us/nednr/gages/00141000
# https://geoconnex.us/nednr/gages/00057000
# https://geoconnex.us/nednr/gages/00019500
# https://geoconnex.us/nednr/gages/00033000
# https://geoconnex.us/nednr/gages/00117000
# https://geoconnex.us/nednr/gages/00037000
# https://geoconnex.us/nednr/gages/06766498
# https://geoconnex.us/nednr/gages/06766499
# https://geoconnex.us/nednr/gages/06766500
# https://geoconnex.us/nednr/gages/06766650
# https://geoconnex.us/nednr/gages/00122000
# https://geoconnex.us/nednr/gages/06767500
# https://geoconnex.us/nednr/gages/00073000
# https://geoconnex.us/nednr/gages/00075000
# https://geoconnex.us/nednr/gages/06770000
# https://geoconnex.us/nednr/gages/00145700
# https://geoconnex.us/nednr/gages/06770195
# https://geoconnex.us/nednr/gages/06770240
# https://geoconnex.us/nednr/gages/00229300
# https://geoconnex.us/nednr/gages/06772000
# https://geoconnex.us/nednr/gages/00130000
# https://geoconnex.us/nednr/gages/00090000
# https://geoconnex.us/nednr/gages/00090200
# https://geoconnex.us/nednr/gages/00091000
# https://geoconnex.us/nednr/gages/00092000
# https://geoconnex.us/nednr/gages/00093000
# https://geoconnex.us/nednr/gages/00047000
# https://geoconnex.us/nednr/gages/00093200
# https://geoconnex.us/nednr/gages/00048000
# https://geoconnex.us/nednr/gages/00049000
# https://geoconnex.us/nednr/gages/06780000
# https://geoconnex.us/nednr/gages/06783500
# https://geoconnex.us/nednr/gages/06784800
# https://geoconnex.us/nednr/gages/00107000
# https://geoconnex.us/nednr/gages/00107100
# https://geoconnex.us/nednr/gages/00107200
# https://geoconnex.us/nednr/gages/00076500
# https://geoconnex.us/nednr/gages/00019800
# https://geoconnex.us/nednr/gages/06787000
# https://geoconnex.us/nednr/gages/00100500
# https://geoconnex.us/nednr/gages/00088500
# https://geoconnex.us/nednr/gages/00054700
# https://geoconnex.us/nednr/gages/06787500
# https://geoconnex.us/nednr/gages/00108000
# https://geoconnex.us/nednr/gages/06788500
# https://geoconnex.us/nednr/gages/00109000
# https://geoconnex.us/nednr/gages/06788988
# https://geoconnex.us/nednr/gages/06791500
# https://geoconnex.us/nednr/gages/06792000
# https://geoconnex.us/nednr/gages/00082100
# https://geoconnex.us/nednr/gages/06793500
# https://geoconnex.us/nednr/gages/06794500
# https://geoconnex.us/nednr/gages/06796973
# https://geoconnex.us/nednr/gages/06798000
# https://geoconnex.us/nednr/gages/06798500
# https://geoconnex.us/nednr/gages/06798780
# https://geoconnex.us/nednr/gages/06799080
# https://geoconnex.us/nednr/gages/00410300
# https://geoconnex.us/nednr/gages/00232500
# https://geoconnex.us/nednr/gages/06799230
# https://geoconnex.us/nednr/gages/06799385
# https://geoconnex.us/nednr/gages/06799450
# https://geoconnex.us/nednr/gages/06799510
# https://geoconnex.us/nednr/gages/00061500
# https://geoconnex.us/nednr/gages/00120500
# https://geoconnex.us/nednr/gages/06831500
# https://geoconnex.us/nednr/gages/06835000
# https://geoconnex.us/nednr/gages/00127000
# https://geoconnex.us/nednr/gages/06837300
# https://geoconnex.us/nednr/gages/06843400
# https://geoconnex.us/nednr/gages/06838500
# https://geoconnex.us/nednr/gages/06839970
# https://geoconnex.us/nednr/gages/06840000
# https://geoconnex.us/nednr/gages/06841000
# https://geoconnex.us/nednr/gages/06842500
# https://geoconnex.us/nednr/gages/00224600
# https://geoconnex.us/nednr/gages/06844000
# https://geoconnex.us/nednr/gages/00231700
# https://geoconnex.us/nednr/gages/06844210
# https://geoconnex.us/nednr/gages/06850000
# https://geoconnex.us/nednr/gages/06851090
# https://geoconnex.us/nednr/gages/06851500
# https://geoconnex.us/nednr/gages/06879900
# https://geoconnex.us/nednr/gages/06880000
# https://geoconnex.us/nednr/gages/06880500
# https://geoconnex.us/nednr/gages/06881200
# https://geoconnex.us/nednr/gages/06881500
# https://geoconnex.us/nednr/gages/06883555
# https://geoconnex.us/nednr/gages/06883940
# https://geoconnex.us/nednr/gages/06884005
# Complete
